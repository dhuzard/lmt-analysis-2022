# %%
import pandas as pd
import os
import glob
import csv

# %%
#read the csv file
df = pd.read_csv("C:/Users/paulc/Desktop/Stage/lmt-analysis-2019/LMT/scripts/TEST_DF_2022/221018_Amphet_Cage1_2-1Amphet.sqlite.csv")
df
# Out:
#       Unnamed: 0                       Filename    Date   Cage  Injection  \
# 0              0  221018_Amphet_Cage1_2-1Amphet  221018  Cage1  2-1Amphet
# 1              1  221018_Amphet_Cage1_2-1Amphet  221018  Cage1  2-1Amphet
# 2              2  221018_Amphet_Cage1_2-1Amphet  221018  Cage1  2-1Amphet
# 3              3  221018_Amphet_Cage1_2-1Amphet  221018  Cage1  2-1Amphet
# 4              4  221018_Amphet_Cage1_2-1Amphet  221018  Cage1  2-1Amphet
# ...          ...                            ...     ...    ...        ...
# 1399        1399  221018_Amphet_Cage1_2-1Amphet  221018  Cage1  2-1Amphet
# 1400        1400  221018_Amphet_Cage1_2-1Amphet  221018  Cage1  2-1Amphet
# 1401        1401  221018_Amphet_Cage1_2-1Amphet  221018  Cage1  2-1Amphet
# 1402        1402  221018_Amphet_Cage1_2-1Amphet  221018  Cage1  2-1Amphet
# 1403        1403  221018_Amphet_Cage1_2-1Amphet  221018  Cage1  2-1Amphet
#
#       Night-Phase  Bin  start_frame  stop_frame           name  ...   GenoB  \
# ...

# %%
#read the path
file_path = "C:/Users/paulc/Desktop/Stage/lmt-analysis-2022/LMT/scripts/Dataframes/"
os.chdir("C:/Users/paulc/Desktop/Stage/lmt-analysis-2022/LMT/scripts/Dataframes/")
#list all the files from the directory
file_list = os.listdir(file_path)
file_list
# Out:
# ['221013_Amphet_Cage1_weekend1.sqlite.csv',
#  '221013_Amphet_Cage2_weekend1.sqlite.csv',
#  '221017_Amphet_Cage1_1-Nacl.sqlite.csv',
#  '221017_Amphet_Cage2_1-NaCl-OnlyOneMouseTracked.sqlite.csv',
#  '221018_Amphet_Cage1_2-1Amphet.sqlite.csv',
#  '221018_Amphet_Cage2_2-1Amphet.sqlite.csv',
#  '221019_Amphet_Cage1_3-2NaCl.sqlite.csv',
#  '221019_Amphet_Cage2_3-1Amphet.sqlite.csv',
#  '221020_Amphet_Cage1_4-1Amphet-1NaCl.sqlite.csv',
#  '221020_Amphet_Cage2_4-1Amphet.sqlite.csv',
#  '221021_Amphet_Cage1_weekend2.sqlite.csv',
#  '221021_Amphet_Cage2_weekend2.sqlite.csv',
#  '221024_Amphet_Cage1_5-2Amphet.sqlite.csv',
#  '221024_Amphet_Cage2_5-3Amphet.sqlite.csv',
#  '221025_Amphet_Cage1_6-2Amphet.sqlite.csv',
#  '221025_Amphet_Cage2_6-3Amphet.sqlite.csv',
#  '221026_Amphet_Cage1_7-2Amphet.sqlite.csv',
#  '221026_Amphet_Cage2_7-3Amphet.sqlite.csv',
#  '221027_Amphet_Cage1_8-2NaCl.sqlite.csv',
#  '221027_Amphet_Cage2_8-3NaCl.sqlite.csv',
#  '221028_Amphet_Cage3_weekend1.sqlite.csv',
# ...

# %%
#read the path
cwd = os.path.abspath('') #list all the files from the directory
file_list
# Out:
# ['221013_Amphet_Cage1_weekend1.sqlite.csv',
#  '221013_Amphet_Cage2_weekend1.sqlite.csv',
#  '221017_Amphet_Cage1_1-Nacl.sqlite.csv',
#  '221017_Amphet_Cage2_1-NaCl-OnlyOneMouseTracked.sqlite.csv',
#  '221018_Amphet_Cage1_2-1Amphet.sqlite.csv',
#  '221018_Amphet_Cage2_2-1Amphet.sqlite.csv',
#  '221019_Amphet_Cage1_3-2NaCl.sqlite.csv',
#  '221019_Amphet_Cage2_3-1Amphet.sqlite.csv',
#  '221020_Amphet_Cage1_4-1Amphet-1NaCl.sqlite.csv',
#  '221020_Amphet_Cage2_4-1Amphet.sqlite.csv',
#  '221021_Amphet_Cage1_weekend2.sqlite.csv',
#  '221021_Amphet_Cage2_weekend2.sqlite.csv',
#  '221024_Amphet_Cage1_5-2Amphet.sqlite.csv',
#  '221024_Amphet_Cage2_5-3Amphet.sqlite.csv',
#  '221025_Amphet_Cage1_6-2Amphet.sqlite.csv',
#  '221025_Amphet_Cage2_6-3Amphet.sqlite.csv',
#  '221026_Amphet_Cage1_7-2Amphet.sqlite.csv',
#  '221026_Amphet_Cage2_7-3Amphet.sqlite.csv',
#  '221027_Amphet_Cage1_8-2NaCl.sqlite.csv',
#  '221027_Amphet_Cage2_8-3NaCl.sqlite.csv',
#  '221028_Amphet_Cage3_weekend1.sqlite.csv',
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\paulc\\Desktop\\Stage\\lmt-analysis-2022\\LMT\\scripts\\Dataframes'

# %%
#list all csv files only
csv_files = glob.glob('*.{}'.format('csv'))
csv_files
# Out:
# ['221013_Amphet_Cage1_weekend1.sqlite.csv',
#  '221013_Amphet_Cage2_weekend1.sqlite.csv',
#  '221017_Amphet_Cage1_1-Nacl.sqlite.csv',
#  '221017_Amphet_Cage2_1-NaCl-OnlyOneMouseTracked.sqlite.csv',
#  '221018_Amphet_Cage1_2-1Amphet.sqlite.csv',
#  '221018_Amphet_Cage2_2-1Amphet.sqlite.csv',
#  '221019_Amphet_Cage1_3-2NaCl.sqlite.csv',
#  '221019_Amphet_Cage2_3-1Amphet.sqlite.csv',
#  '221020_Amphet_Cage1_4-1Amphet-1NaCl.sqlite.csv',
#  '221020_Amphet_Cage2_4-1Amphet.sqlite.csv',
#  '221021_Amphet_Cage1_weekend2.sqlite.csv',
#  '221021_Amphet_Cage2_weekend2.sqlite.csv',
#  '221024_Amphet_Cage1_5-2Amphet.sqlite.csv',
#  '221024_Amphet_Cage2_5-3Amphet.sqlite.csv',
#  '221025_Amphet_Cage1_6-2Amphet.sqlite.csv',
#  '221025_Amphet_Cage2_6-3Amphet.sqlite.csv',
#  '221026_Amphet_Cage1_7-2Amphet.sqlite.csv',
#  '221026_Amphet_Cage2_7-3Amphet.sqlite.csv',
#  '221027_Amphet_Cage1_8-2NaCl.sqlite.csv',
#  '221027_Amphet_Cage2_8-3NaCl.sqlite.csv',
#  '221028_Amphet_Cage3_weekend1.sqlite.csv',
# ...

# %%
df_append = pd.DataFrame() #append all files together

for file in csv_files:
            df_temp = pd.read_csv(file)
            df_append = df_append.append(df_temp, ignore_index=True)
            
df_append
# Out:
# C:\Users\paulc\AppData\Local\Temp\ipykernel_31960\945781501.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\paulc\AppData\Local\Temp\ipykernel_31960\945781501.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\paulc\AppData\Local\Temp\ipykernel_31960\945781501.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\paulc\AppData\Local\Temp\ipykernel_31960\945781501.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df_append.to_csv("C:/Users/paulc/Desktop/Stage/lmt-analysis-2022/LMT/scripts/Dataframes/Merge.csv")
df_append.pop("Unnamed: 0")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 0'
#
# ...
