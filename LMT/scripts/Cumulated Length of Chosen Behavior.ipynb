# %% [markdown]
# # Cumulated Graph of the Chosen Behavior:
#
# This script provides the figure for cumulated water point. (note that you need to build the event "Water Stop" to get this graph)
#
# *Warning: we set the waterpoint at the bottom right of the cage. If you use another location, change the code of the rebuildWaterPoint.py file.*
#
# | ![](../images/cumulatedwaterpoint1.jpg) ![](../images/cumulatedwaterpoint2.jpg) ![](../images/cumulatedwaterpoint3.jpg) ![](../images/cumulatedwaterpoint4.jpg)
# |:--:|
# |Example of cumulated water point|

# %%
import sys
sys.path.insert(1, "../")

import sqlite3
from lmtanalysis.Animal import *
import matplotlib.pyplot as plt
from lmtanalysis.Event import *
from lmtanalysis.Measure import *

import lmtanalysis
from tkinter.filedialog import askopenfilename
from tabulate import tabulate
from collections import Counter
import collections
import xlsxwriter
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import os
from lmtanalysis.FileUtil import getFilesToProcess
from lmtanalysis.Util import convert_to_d_h_m_s, getMinTMaxTInput,getFrameInput


def frameToTimeTicker(x, pos):
   
    vals= convert_to_d_h_m_s( x )
    return "D{0} - {1:02d}:{2:02d}".format( int(vals[0])+1, int(vals[1]), int(vals[2]) )
    
if __name__ == '__main__':
    
    print("Code launched.")
    #Choose the files to process
    files = getFilesToProcess()
    tmin = getFrameInput("Start")
    tmax = getFrameInput("End")

    behavioralEvents = ["Contact", "Oral-oral Contact", "Oral-genital Contact", "Side by side Contact", 
                        "Side by side Contact, opposite way", "Social approach", "Get away", "Approach contact", 
                        "Approach rear", "Break contact", "FollowZone Isolated", "Train2", "Group2", "Group3", "Group4",
                        "Group 3 break", "Group 3 make", "Group 4 break", "Group 4 make", "Move isolated", 
                        "Move in contact", "Rear isolated", "Rear in contact", "Stop isolated", 
                        "WallJump","totalDistance", "Fight", "Won Fight", "Lost Fight", "SAP"]
    print(behavioralEvents)
    behaviorToPlot = input("Which behavior do you want to plot the Cumulated graph?")
    
    saveFile = f"figTimeLine-{behaviorToPlot}"

    for file in files:
        print(file)
        expName = file[-30:-7] #Select the name of XP in the filename
        print("expName is: ", expName )
        
        connection = sqlite3.connect( file )
    
        pool = AnimalPool( )
        pool.loadAnimals( connection )
        """        
        pool.loadDetection( start = tmin, end = tmax, lightLoad=True)
        """
        #Load the timeline of the event over all individuals
        behaviorTimeLine = {}
        for animal in pool.animalDictionnary.keys():
            print ( pool.animalDictionnary[animal].RFID )
            behaviorTimeLine[animal] = EventTimeLine( connection, behaviorToPlot, idA=animal, minFrame=tmin, maxFrame=tmax )
#             behaviorTimeLine[animal].removeEventsBelowLength( maxLen = MIN_WATER_STOP_DURATION )
        
        
        #Compute cumulative time spent at water point
        fig, ax = plt.subplots( 1,1 , figsize=(8, 2 ) )
        
        ''' build the plot '''
        ymin=-30
        fig, ax = plt.subplots(1,1 , figsize=(8, 2 ) )
        ax = plt.gca() # get current axis
        ax.set_xlabel("time")
        ax.set_xlim([0, tmax])
        #ax.set_ylim([ymin, ymax])
        
        #set x axis
        formatter = matplotlib.ticker.FuncFormatter( frameToTimeTicker )
        ax.xaxis.set_major_formatter(formatter)
        ax.tick_params(labelsize=6 )
        ax.xaxis.set_major_locator(ticker.MultipleLocator( 30 * 60 * 60 * 12 ))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator( 30 * 60 * 60 ))
                
        #draw the rectangles for the nights
        print("loading night events for file " + file)
        nightTimeLine = EventTimeLine( connection, "night" , minFrame=tmin, maxFrame=tmax )
        
        for nightEvent in nightTimeLine.getEventList():
            ax.axvspan( nightEvent.startFrame, nightEvent.endFrame, alpha=0.1, color='black')
            ax.text( nightEvent.startFrame+(nightEvent.endFrame-nightEvent.startFrame)/2 , 200 , "dark phase" ,fontsize=6, ha='center')
        
        behaviorDuration = {}
        timeBin = 1
        
        #Print the name and genotype of the animals on the graph, with the corresponding colors and the total distance traveled over the experiment
        legendHeight = 60
        rfids_legend = []
        geno_legend = []
        for animal in pool.animalDictionnary.keys():
            rfids_legend.append(pool.animalDictionnary[animal].RFID[:-4])
            geno_legend.append(pool.animalDictionnary[animal].genotype)
            if "SFC" in pool.animalDictionnary[animal].genotype:
                color = "red"
            else:
                color="blue"
            print ( pool.animalDictionnary[animal].RFID )
            ax.text(30*60*60, legendHeight, "{} {}".format(pool.animalDictionnary[animal].RFID[5:], 
                                                           pool.animalDictionnary[animal].genotype), color = color, fontsize=5)
            
#                     color=getAnimalColor(animal), fontsize=5 )
            legendHeight += 30 
             
        for animal in pool.animalDictionnary.keys():
            listCumulated = []
            listValue = behaviorTimeLine[animal].getDurationEventInTimeBin( tmin=tmin, tmax=tmax, binSize=timeBin*oneMinute)
            cumul = 0
            for value in listValue:
                cumul+= value
                listCumulated.append( cumul )
            behaviorDuration[animal ]= listCumulated
        
        nTimeBins = len(behaviorDuration[1])
        print(nTimeBins)
        
        abs = [1*oneMinute]
        for t in range(1, nTimeBins):
            x = abs[t-1] + timeBin*oneMinute
            abs.append(x)
            
        for animal in behaviorDuration:
            if "Amphet" in pool.animalDictionnary[animal].genotype:
                color = "red"
            else:
                color="blue"
            ax.plot( abs, behaviorDuration[animal] , color= color) # color= getAnimalColor( animal )
                
        ax.legend(geno_legend) #ADD THE GENOTYPE AS LEGEND
        fig.suptitle(f"{expName} / {behaviorToPlot}")

        figName = f"FigCumul-{behaviorToPlot}_{expName}.png"
        print (behaviorToPlot)
        print(expName)
        print ("Saving figure..." , figName )
        fig.savefig( figName ,dpi=100)
        
#         plt.show()
        plt.close( fig )
        connection.close() #Stop connection to the DBs
        print( "*** ALL JOBS DONE *** ")
# Out:
# Code launched.
# Start :  0
# Entry (in frame) : 0
# End :  500000
# Entry (in frame) : 500000
# ['Contact', 'Oral-oral Contact', 'Oral-genital Contact', 'Side by side Contact', 'Side by side Contact, opposite way', 'Social approach', 'Get away', 'Approach contact', 'Approach rear', 'Break contact', 'FollowZone Isolated', 'Train2', 'Group2', 'Group3', 'Group4', 'Group 3 break', 'Group 3 make', 'Group 4 break', 'Group 4 make', 'Move isolated', 'Move in contact', 'Rear isolated', 'Rear in contact', 'Stop isolated', 'WallJump', 'totalDistance', 'Fight', 'Won Fight', 'Lost Fight', 'SAP']
# Which behavior do you want to plot the Cumulated graph? Move isolated
# E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221031_Amphet_Cage3_1-3NaCl.sqlite
# expName is:  31_Amphet_Cage3_1-3NaCl
# Loading animals ...
# Fields available in lmtanalysis Z:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004849177 Genotype:NaCl User1:None
# Animal Id:2 Name:B RFID:000004849427 Genotype:NaCl User1:None
# Animal Id:3 Name:C RFID:000004849094 Genotype:NaCl User1:None
# 000004849177
# Move isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 8096  records loaded in  60.948962688446045 S )
# 000004849427
# Move isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 8053  records loaded in  0.6557080745697021 S )
# 000004849094
# Move isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 7811  records loaded in  0.6576700210571289 S )
# loading night events for file E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221031_Amphet_Cage3_1-3NaCl.sqlite
# night  Id( None , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 0  records loaded in  0.6106841564178467 S )
# 000004849177
# 000004849427
# 000004849094
# 278
# Move isolated
# 31_Amphet_Cage3_1-3NaCl
# Saving figure... FigCumul-Move isolated_31_Amphet_Cage3_1-3NaCl.png
# *** ALL JOBS DONE ***
# E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221031_Amphet_Cage4_1-3NaCl.sqlite
# expName is:  31_Amphet_Cage4_1-3NaCl
# Loading animals ...
# Fields available in lmtanalysis Z:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004849320 Genotype:NaCl User1:None
# Animal Id:2 Name:B RFID:000004849491 Genotype:NaCl User1:None
# Animal Id:3 Name:C RFID:000004849182 Genotype:NaCl User1:None
# 000004849320
# Move isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 2078  records loaded in  37.019068479537964 S )
# 000004849491
# Move isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 2586  records loaded in  0.448047399520874 S )
# 000004849182
# Move isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 2468  records loaded in  0.44884538650512695 S )
# loading night events for file E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221031_Amphet_Cage4_1-3NaCl.sqlite
# night  Id( None , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 0  records loaded in  0.42846250534057617 S )
# 000004849320
# 000004849491
# 000004849182
# 278
# Move isolated
# 31_Amphet_Cage4_1-3NaCl
# Saving figure... FigCumul-Move isolated_31_Amphet_Cage4_1-3NaCl.png
# *** ALL JOBS DONE ***
# E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221101_Amphet_Cage3_2-1Amphet.sqlite
# expName is:  _Amphet_Cage3_2-1Amphet
# Loading animals ...
# Fields available in lmtanalysis Z:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:3 Name:C RFID:000004849427 Genotype:Amphet User1:None
# Animal Id:1 Name:A RFID:000004849094 Genotype:NaCl User1:None
# Animal Id:2 Name:B RFID:000004849177 Genotype:NaCl User1:None
# 000004849427
# Move isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 7657  records loaded in  27.156420946121216 S )
# 000004849094
# Move isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 8110  records loaded in  0.44200873374938965 S )
# 000004849177
# Move isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 8137  records loaded in  0.48653364181518555 S )
# loading night events for file E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221101_Amphet_Cage3_2-1Amphet.sqlite
# night  Id( None , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 0  records loaded in  0.4051380157470703 S )
# 000004849427
# 000004849094
# 000004849177
# 278
# Move isolated
# _Amphet_Cage3_2-1Amphet
# Saving figure... FigCumul-Move isolated__Amphet_Cage3_2-1Amphet.png
# *** ALL JOBS DONE ***
# E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221101_Amphet_Cage4_2-1Amphet.sqlite
# expName is:  _Amphet_Cage4_2-1Amphet
# Loading animals ...
# Fields available in lmtanalysis Z:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:2 Name:B RFID:000004849320 Genotype:Amphet User1:None
# Animal Id:1 Name:A RFID:000004849182 Genotype:NaCl User1:None
# Animal Id:3 Name:C RFID:000004849491 Genotype:NaCl User1:None
# 000004849320
# Move isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 5150  records loaded in  42.58445453643799 S )
# 000004849182
# Move isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 6825  records loaded in  0.570798397064209 S )
# 000004849491
# Move isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 4014  records loaded in  0.6017200946807861 S )
# loading night events for file E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221101_Amphet_Cage4_2-1Amphet.sqlite
# night  Id( None , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 0  records loaded in  0.5318329334259033 S )
# 000004849320
# 000004849182
# 000004849491
# 278
# Move isolated
# _Amphet_Cage4_2-1Amphet
# Saving figure... FigCumul-Move isolated__Amphet_Cage4_2-1Amphet.png
# *** ALL JOBS DONE ***
# E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221102_Amphet_Cage3_3-1Amphet.sqlite
# expName is:  _Amphet_Cage3_3-1Amphet
# Loading animals ...
# Fields available in lmtanalysis Z:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:2 Name:B RFID:000004849177 Genotype:Amphet User1:None
# Animal Id:1 Name:A RFID:000004849427 Genotype:NaCl User1:None
# Animal Id:3 Name:C RFID:000004849094 Genotype:NaCl User1:None
# 000004849177
# Move isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 12272  records loaded in  26.617866277694702 S )
# 000004849427
# Move isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 5538  records loaded in  0.35965681076049805 S )
# 000004849094
# Move isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 6441  records loaded in  0.4068763256072998 S )
# loading night events for file E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221102_Amphet_Cage3_3-1Amphet.sqlite
# night  Id( None , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 0  records loaded in  0.32170557975769043 S )
# 000004849177
# 000004849427
# 000004849094
# 278
# Move isolated
# _Amphet_Cage3_3-1Amphet
# Saving figure... FigCumul-Move isolated__Amphet_Cage3_3-1Amphet.png
# *** ALL JOBS DONE ***
# E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221102_Amphet_Cage4_3-1Amphet.sqlite
# expName is:  _Amphet_Cage4_3-1Amphet
# Loading animals ...
# Fields available in lmtanalysis Z:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:2 Name:B RFID:000004849182 Genotype:Amphet User1:None
# Animal Id:1 Name:A RFID:000004849491 Genotype:NaCl User1:None
# Animal Id:3 Name:C RFID:000004849320 Genotype:NaCl User1:None
# 000004849182
# Move isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 5465  records loaded in  54.8863582611084 S )
# 000004849491
# Move isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 4971  records loaded in  0.6300184726715088 S )
# 000004849320
# Move isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 4717  records loaded in  0.637861967086792 S )
# loading night events for file E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221102_Amphet_Cage4_3-1Amphet.sqlite
# night  Id( None , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 0  records loaded in  0.6158621311187744 S )
# 000004849182
# 000004849491
# 000004849320
# 278
# Move isolated
# _Amphet_Cage4_3-1Amphet
# Saving figure... FigCumul-Move isolated__Amphet_Cage4_3-1Amphet.png
# *** ALL JOBS DONE ***
# E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221103_Amphet_Cage3_4-1Amphet.sqlite
# expName is:  _Amphet_Cage3_4-1Amphet
# Loading animals ...
# Fields available in lmtanalysis Z:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:3 Name:C RFID:000004849094 Genotype:Amphet User1:None
# Animal Id:1 Name:A RFID:000004849177 Genotype:NaCl User1:None
# Animal Id:2 Name:B RFID:000004849427 Genotype:NaCl User1:None
# 000004849094
# Move isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 7667  records loaded in  54.95461058616638 S )
# 000004849177
# Move isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 8301  records loaded in  0.6300275325775146 S )
# 000004849427
# Move isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 8645  records loaded in  0.6252176761627197 S )
# loading night events for file E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221103_Amphet_Cage3_4-1Amphet.sqlite
# night  Id( None , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 0  records loaded in  0.5783731937408447 S )
# 000004849094
# 000004849177
# 000004849427
# 278
# Move isolated
# _Amphet_Cage3_4-1Amphet
# Saving figure... FigCumul-Move isolated__Amphet_Cage3_4-1Amphet.png
# *** ALL JOBS DONE ***
# E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221103_Amphet_Cage4_4-1Amphet.sqlite
# expName is:  _Amphet_Cage4_4-1Amphet
# Loading animals ...
# Fields available in lmtanalysis Z:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:2 Name:B RFID:000004849491 Genotype:Amphet User1:None
# Animal Id:1 Name:A RFID:000004849182 Genotype:NaCl User1:None
# Animal Id:3 Name:C RFID:000004849320 Genotype:NaCl User1:None
# 000004849491
# Move isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 3981  records loaded in  49.793092489242554 S )
# 000004849182
# Move isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 3245  records loaded in  0.5704689025878906 S )
# 000004849320
# Move isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 3492  records loaded in  0.5682570934295654 S )
# loading night events for file E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221103_Amphet_Cage4_4-1Amphet.sqlite
# night  Id( None , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 0  records loaded in  0.5456728935241699 S )
# 000004849491
# 000004849182
# 000004849320
# 278
# Move isolated
# _Amphet_Cage4_4-1Amphet
# Saving figure... FigCumul-Move isolated__Amphet_Cage4_4-1Amphet.png
# *** ALL JOBS DONE ***
# E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221107_Amphet_Cage3_5-3Amphet.sqlite
# expName is:  _Amphet_Cage3_5-3Amphet
# Loading animals ...
# Fields available in lmtanalysis Z:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004849094 Genotype:Amphet User1:None
# Animal Id:2 Name:B RFID:000004849427 Genotype:Amphet User1:None
# Animal Id:3 Name:C RFID:000004849177 Genotype:Amphet User1:None
# 000004849094
# Move isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 7202  records loaded in  40.54781794548035 S )
# 000004849427
# Move isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 6085  records loaded in  0.4598240852355957 S )
# 000004849177
# Move isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 5183  records loaded in  0.49762415885925293 S )
# loading night events for file E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221107_Amphet_Cage3_5-3Amphet.sqlite
# night  Id( None , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 0  records loaded in  0.4239184856414795 S )
# 000004849094
# 000004849427
# 000004849177
# 278
# Move isolated
# _Amphet_Cage3_5-3Amphet
# Saving figure... FigCumul-Move isolated__Amphet_Cage3_5-3Amphet.png
# *** ALL JOBS DONE ***
# E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221107_Amphet_Cage4_5-3Amphet.sqlite
# expName is:  _Amphet_Cage4_5-3Amphet
# Loading animals ...
# Fields available in lmtanalysis Z:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004849491 Genotype:Amphet User1:None
# Animal Id:2 Name:B RFID:000004849182 Genotype:Amphet User1:None
# Animal Id:3 Name:C RFID:000004849320 Genotype:Amphet User1:None
# 000004849491
# Move isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 5139  records loaded in  45.62879729270935 S )
# 000004849182
# Move isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 2994  records loaded in  0.5566375255584717 S )
# 000004849320
# Move isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 4255  records loaded in  0.5552167892456055 S )
# loading night events for file E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221107_Amphet_Cage4_5-3Amphet.sqlite
# night  Id( None , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 0  records loaded in  0.5290083885192871 S )
# 000004849491
# 000004849182
# 000004849320
# 278
# Move isolated
# _Amphet_Cage4_5-3Amphet
# Saving figure... FigCumul-Move isolated__Amphet_Cage4_5-3Amphet.png
# *** ALL JOBS DONE ***
# E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221108_Amphet_Cage3_6-3Amphet.sqlite
# expName is:  _Amphet_Cage3_6-3Amphet
# Loading animals ...
# Fields available in lmtanalysis Z:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004849427 Genotype:Amphet User1:None
# Animal Id:2 Name:B RFID:000004849094 Genotype:Amphet User1:None
# Animal Id:3 Name:C RFID:000004849177 Genotype:Amphet User1:None
# 000004849427
# Move isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 11045  records loaded in  59.02852487564087 S )
# 000004849094
# Move isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 11377  records loaded in  0.6251552104949951 S )
# 000004849177
# Move isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 10298  records loaded in  0.6231536865234375 S )
# loading night events for file E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221108_Amphet_Cage3_6-3Amphet.sqlite
# night  Id( None , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 0  records loaded in  0.5191285610198975 S )
# 000004849427
# 000004849094
# 000004849177
# 278
# Move isolated
# _Amphet_Cage3_6-3Amphet
# Saving figure... FigCumul-Move isolated__Amphet_Cage3_6-3Amphet.png
# *** ALL JOBS DONE ***
# E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221108_Amphet_Cage4_6-3Amphet.sqlite
# expName is:  _Amphet_Cage4_6-3Amphet
# Loading animals ...
# Fields available in lmtanalysis Z:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004849182 Genotype:Amphet User1:None
# Animal Id:2 Name:B RFID:000004849491 Genotype:Amphet User1:None
# Animal Id:3 Name:C RFID:000004849320 Genotype:Amphet User1:None
# 000004849182
# Move isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 0  records loaded in  8.217792510986328 S )
# 000004849491
# Move isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 0  records loaded in  0.17205071449279785 S )
# 000004849320
# Move isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 0  records loaded in  0.1705472469329834 S )
# loading night events for file E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221108_Amphet_Cage4_6-3Amphet.sqlite
# night  Id( None , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 0  records loaded in  0.17001056671142578 S )
# 000004849182
# 000004849491
# 000004849320
# 278
# Move isolated
# _Amphet_Cage4_6-3Amphet
# Saving figure... FigCumul-Move isolated__Amphet_Cage4_6-3Amphet.png
# *** ALL JOBS DONE ***
# E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221109_Amphet_Cage3_7-3Amphet.sqlite
# expName is:  _Amphet_Cage3_7-3Amphet
# Loading animals ...
# Fields available in lmtanalysis Z:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004849177 Genotype:Amphet User1:None
# Animal Id:2 Name:B RFID:000004849094 Genotype:Amphet User1:None
# Animal Id:3 Name:C RFID:000004849427 Genotype:Amphet User1:None
# 000004849177
# Move isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 10778  records loaded in  62.61737561225891 S )
# 000004849094
# Move isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 11006  records loaded in  0.64780592918396 S )
# 000004849427
# Move isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 10174  records loaded in  0.713456392288208 S )
# loading night events for file E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221109_Amphet_Cage3_7-3Amphet.sqlite
# night  Id( None , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 0  records loaded in  0.5510022640228271 S )
# 000004849177
# 000004849094
# 000004849427
# 278
# Move isolated
# _Amphet_Cage3_7-3Amphet
# Saving figure... FigCumul-Move isolated__Amphet_Cage3_7-3Amphet.png
# *** ALL JOBS DONE ***
# E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221109_Amphet_Cage4_7-3Amphet.sqlite
# expName is:  _Amphet_Cage4_7-3Amphet
# Loading animals ...
# Fields available in lmtanalysis Z:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004849320 Genotype:Amphet User1:None
# Animal Id:2 Name:B RFID:000004849182 Genotype:Amphet User1:None
# Animal Id:3 Name:C RFID:000004849491 Genotype:Amphet User1:None
# 000004849320
# Move isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 8591  records loaded in  62.47966384887695 S )
# 000004849182
# Move isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 9885  records loaded in  0.6193974018096924 S )
# 000004849491
# Move isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 9700  records loaded in  0.6352198123931885 S )
# loading night events for file E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221109_Amphet_Cage4_7-3Amphet.sqlite
# night  Id( None , None , None , None ) Min/maxFrame: ( 0 / 500000 ) Loaded ( 0  records loaded in  0.5326285362243652 S )
# 000004849320
# 000004849182
# 000004849491
# 278
# Move isolated
# _Amphet_Cage4_7-3Amphet
# Saving figure... FigCumul-Move isolated__Amphet_Cage4_7-3Amphet.png
# *** ALL JOBS DONE ***

# %%
geno_legend
# Out:
# ['OBS', 'SFC+']
