# %% [markdown]
# # Animal profile
#
# This file creates the profile output for a group of animals.
#
# | ![](../images/profile.jpg) |
# |:--:|
# |Example of profile. 1 point per animal. Each color represents one cage|
#
# This code computes the total time spent in each behaviour as well as the total number of occurrences of this behaviour for each individual. You can choose to compute this profile either over all the experiment or for each night separately. It provides a plot for the total duration of all the different events and a plot for the total number of occurrences of each behaviour as pdf files. It also provides a txt file with all individual values for each variable, as well as statistics (mixed model for each trait, uncorrected: trait as a function of genotype, with a group effect).

# %%
'''
Created on 13 sept. 2017

@author: Fabrice de Chaumont and Elodie Ey
'''

import sys
sys.path.insert(1, "../")

import sqlite3
from lmtanalysis.Animal import *
import numpy as np
import matplotlib.pyplot as plt
from lmtanalysis.Event import *
from lmtanalysis.Measure import *
import colorsys
from collections import Counter
import seaborn as sns

from tkinter.filedialog import askopenfilename
from lmtanalysis.Util import getMinTMaxTAndFileNameInput
from lmtanalysis.EventTimeLineCache import EventTimeLineCached
from lmtanalysis.FileUtil import getFilesToProcess
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas
from datetime import datetime


def computeProfile(file, minT, maxT, night):
    
    connection = sqlite3.connect( file )
    
    pool = AnimalPool()
    pool.loadAnimals( connection )
    
    animalData = {} # will then be the 'profileData'
    # animalData[night] = night #Assigning the night

    for animal in pool.animalDictionnary.keys():
        print(f"computing individual animal:{animal}")
        rfid = pool.animalDictionnary[animal].RFID
        print(f"RFID:{rfid}")
        animalData[rfid]= {}        
        #store the animal
        animalData[rfid]["animal"] = pool.animalDictionnary[animal]
        animalData[rfid]["file"] = file
        
        genoA = None
        try:
            genoA=pool.animalDictionnary[animal].genotype
        except:
            pass
                    
        for behavEvent in behavioralEvents[:-2]:
            
            print(f"computing individual event: {behavEvent}")    
            
            behavEventTimeLine = EventTimeLineCached( connection, file, behavEvent, animal, minFrame=minT, maxFrame=maxT )
            
            totalEventDuration = behavEventTimeLine.getTotalLength()
            nbEvent = behavEventTimeLine.getNumberOfEvent(minFrame = minT, maxFrame = maxT )
            print( "total event duration: " , totalEventDuration )                
            animalData[rfid][behavEventTimeLine.eventName+" TotalLen"] = totalEventDuration
            animalData[rfid][behavEventTimeLine.eventName+" Nb"] = nbEvent
            
            print(behavEventTimeLine.eventName, genoA, behavEventTimeLine.idA, totalEventDuration, nbEvent)

    header = ["file","strain","sex","group","day","exp","RFID","genotype", "user1", "minTime","maxTime"]
    for name in header:
        text_file.write( "{}\t".format ( name ) ) 
    for kAnimal in animalData:    
        #identify the experiment where the animal comes from:
        animalData[kAnimal]["experiment"] = file  #HD: What does it do ?
        #compute the total distance traveled
        COMPUTE_TOTAL_DISTANCE = True #Change to 'True' OR 'False' if you want OR not to compute total Distance
        if COMPUTE_TOTAL_DISTANCE == True:
            animalData[kAnimal]["animal"].loadDetection( start=minT, end=maxT, lightLoad = True )
            animalData[kAnimal]["totalDistance"] = animalData[kAnimal]["animal"].getDistance( tmin=minT,tmax=maxT)/100
        else:
            animalData[kAnimal]["totalDistance"] = "totalDistance"
        
    # write event keys
    firstAnimalKey = next(iter(animalData))
    firstAnimal = animalData[firstAnimalKey]
    for k in firstAnimal.keys():
        text_file.write( "{}\t".format( k.replace(" ", "") ) )
    text_file.write("\n")
    
    for kAnimal in animalData:
        text_file.write( "{}\t".format( file ) )
        text_file.write( "{}\t".format( "strain" ) )
        text_file.write( "{}\t".format( "sex" ) )
        text_file.write( "{}\t".format( "group" ) )
        text_file.write( "{}\t".format( f"night-{night}" ) )
        text_file.write( "{}\t".format( "exp" ) )
        text_file.write( "{}\t".format( animalData[kAnimal]["animal"].RFID ) )
        text_file.write( "{}\t".format( animalData[kAnimal]["animal"].genotype ) )
        text_file.write( "{}\t".format( animalData[kAnimal]["animal"].user1 ) )
        text_file.write( "{}\t".format( minT ) )
        text_file.write( "{}\t".format( maxT ) )

        for kEvent in firstAnimal.keys():
            text_file.write( "{}\t".format( animalData[kAnimal][kEvent] ) )
        text_file.write( "\n" )
        
    connection.close() #Close the connection to the database (to save memory?)
    return animalData


def getProfileValues(profileData, night=0, event=None, nbNightsDic=None):

#     print(f"in getProfileValues, night is = {night}")
    dataDic = {}
    dataDic["genotype"] = []
    dataDic["value"] = []
    dataDic["exp"] = []
    
    for file in profileData.keys():
        if night == 0 or night <= nbNightsDic[file]: #Check if there are more nights in the file
            for animal in profileData[file][night]: # BUG WITH night=1 ?
                if (genoToRemove.lower() != "no") & (genoToRemove != ""): #Test that it is not "NO" or ""
                    if genoToRemove in profileData[file][night][animal]["animal"].genotype:  #SKIPS THE 'genoToRemove' ANIMALS !!!
                        continue
                dataDic["value"].append(profileData[file][night][animal][event])
                dataDic["exp"].append(profileData[file][night][animal]["experiment"])
                dataDic["genotype"].append(profileData[file][night][animal]["animal"].genotype)
        else:
            print(f"During night#{night}, file '{file}' EXLUDED !!!")
            continue
    return dataDic


def plotProfileDataDuration(profileData, night, valueCat, text_file_name, nbNightsDic=None):
    fig, axes = plt.subplots(nrows=5, ncols=6, figsize=(14, 12))
#     plt.xticks(rotation=45, horizontalalignment='right', fontweight='light') #X-axis 45° angle

    row=0
    col=0
    fig.suptitle(t=f"{valueCat} of events (night {night})", y=1.2, fontweight= 'bold')
    
    #plot the data for each behavioural event
    for behavEvent in behavioralEvents[:-2]: # HD: WHY '-2' ??? Not taking the Last Behavior (totalDist) ?
        event = behavEvent+valueCat
        print("event: ", event)

        profileValueDictionary = getProfileValues(profileData=profileData, night=night,
                                                  event=event, nbNightsDic=nbNightsDic)
        y = profileValueDictionary["value"]
        x = profileValueDictionary["genotype"]
        genotypeType = Counter(x)
        group = profileValueDictionary["exp"]
        
        print("y: ", y)
        print("x: ", x)
        print("group: ", group)
        experimentType = Counter(group)
        print("Nb of experiments: ", len(experimentType))
        
        axes[row,col].set_xlim(-0.5, 1.5)
        axes[row,col].set_ylim(min(y)-0.2*max(y), max(y)+0.2*max(y))
        sns.stripplot(x, y, jitter=True, hue=group, s=5, ax=axes[row,col] )
        axes[row,col].set_title(behavEvent)
        axes[row,col].set_ylabel("{} (frames)".format(valueCat))
        axes[row,col].legend().set_visible(False)
        axes[row,col].spines['right'].set_visible(False)
        axes[row,col].spines['top'].set_visible(False)
                
        if col<5:
            col+=1
            row=row
        else:
            col=0
            row+=1

    # Plot the data for the total distance traveled   
    print("plot Total Distance")
    profileValueDictionary = getProfileValues(profileData=profileData, night=night, 
                                              event="totalDistance", nbNightsDic=nbNightsDic)
    y = profileValueDictionary["value"]
    x = profileValueDictionary["genotype"]
    genotypeType = Counter(x)
    group = profileValueDictionary["exp"]
    
    print("y: ", y)
    print("x: ", x)
    print("group: ", group)
    experimentType = Counter(group)
    print("Nb of experiments: ", len(experimentType))
    
    axes[row,col].set_xlim(-0.5, 1.5)
    axes[row,col].set_ylim(min(y)-0.2*max(y), max(y)+0.2*max(y))
    sns.stripplot(x, y, jitter=True, hue=group, s=5, ax=axes[row,col] )
    axes[row,col].set_title("Activity")
    axes[row,col].set_ylabel("total distance (m)")
    axes[row,col].legend().set_visible(False)
    axes[row,col].spines['right'].set_visible(False)
    axes[row,col].spines['top'].set_visible(False)
    
    if col<7:
        col+=1
        row=row
    else:
        col=0
        row+=1
    
    #ROTATE THE X-AXIS OF ALL SUBPLOTS
    for ax in fig.axes:
        matplotlib.pyplot.sca(ax)
        plt.xticks(rotation=45)
        
    fig.tight_layout()
    figFileName = f"{text_file_name}_{valueCat}_night_{night}.png"
    print("Saving " , figFileName )
    fig.savefig( figFileName ,dpi=100)
    plt.close( fig )
    

def testProfileData(profileData=None, night=0, eventListNames=None, valueCat="", 
                    text_file=None, nbNightsDic=None):
    for behavEvent in eventListNames:
        event = behavEvent+valueCat
        print("event: ", event)
        text_file.write("Test for the event: {} night {}".format( event, night ) )
        
        profileValueDictionary = getProfileValues(profileData=profileData, night=night, 
                                                  event=event, nbNightsDic=nbNightsDic)
        
        dfData = pandas.DataFrame({'group': profileValueDictionary["exp"],
                                   'genotype': profileValueDictionary["genotype"],
                                   'value': profileValueDictionary["value"]})
        
        #pandas.DataFrame(dfData).info()
        
        #Mixed model: variable to explain: value; fixed factor = genotype; random effect: group
        model = smf.mixedlm("value ~ genotype", dfData, groups = dfData["group"])  #Creates the model 
        result = model.fit()  #Run model
        print(result.summary())  #Print summary
        text_file.write(result.summary().as_text())


if __name__ == '__main__':
    
    print("Code launched.")

    # datetime object containing current date and time
    now = datetime.now()
    print("Start @", now)
    
    files = getFilesToProcess()
    tmin, tmax, text_file, text_file_name = getMinTMaxTAndFileNameInput()

    profileData = {}
    nightComputation = input("Compute profile only during night events (Yes or No)? ")
    doStats = input("Do you want to do Stats on your data (Yes or No)? (Warning: MORE THAN ONE FILE REQUIRED): ")
    genoToRemove = ""
    while genoToRemove == "":
        genoToRemove = input("Is there a Genotype to exclude? (a 'keyword' or 'NO' if None) DON'T LEAVE BLANK!): ")
    nbMaxAnimal = int(input("What's the MAX number of Animals per LMT ? (1,2,3 or 4): "))
    
    ### List of events to be computed within the behavioral profile     ###
    ### and header for the computation of the total distance travelled. ###
    
    if nbMaxAnimal == 2:
        behavioralEvents = ["Contact", "Oral-oral Contact", "Oral-genital Contact", "Side by side Contact", 
                            "Side by side Contact, opposite way", "Social approach", "Get away", "Break contact", 
                            "Approach contact","Approach rear", "FollowZone Isolated", "Train2", "Group2", 
                            "Move isolated", "Move in contact", "Rear isolated", "Rear in contact", "Stop isolated", 
                            "WallJump","Water Zone","Fight","Gets to Fight","Won Fight","Lost Fight", "SAP",
                            "extra", "totalDistance"]
    if nbMaxAnimal == 3:
        behavioralEvents = ["Contact", "Oral-oral Contact", "Oral-genital Contact", "Side by side Contact", 
                            "Side by side Contact, opposite way", "Social approach", "Get away", "Approach contact", 
                            "Approach rear", "Break contact", "FollowZone Isolated", "Train2", "Group2", "Group3",
                            "Group 3 break", "Group 3 make", "Move isolated", "Move in contact", "Rear isolated", "SAP",
                            "Rear in contact", "Stop isolated", "WallJump","extra", "totalDistance"]
    if nbMaxAnimal == 4:
        behavioralEvents = ["Contact", "Oral-oral Contact", "Oral-genital Contact", "Side by side Contact", 
                            "Side by side Contact, opposite way", "Social approach", "Get away", "Approach contact", 
                            "Approach rear", "Break contact", "FollowZone Isolated", "Train2", "Group2", "Group3", "Group4",
                            "Group 3 break", "Group 3 make", "Group 4 break", "Group 4 make", "Move isolated", "SAP",
                            "Move in contact", "Rear isolated", "Rear in contact", "Stop isolated", 
                            "WallJump","extra", "totalDistance"]
    
#     behavioralEvents = ["Contact", "Oral-oral Contact", "Oral-genital Contact", "Side by side Contact", 
#                         "Side by side Contact, opposite way", "Social approach", "Get away", "Approach contact", 
#                         "Approach rear", "Break contact", "FollowZone Isolated", "Train2", "Group2", "Group3", "Group4",
#                         "Group 3 break", "Group 3 make", "Group 4 break", "Group 4 make", "Move isolated", 
#                         "Move in contact", "Rear isolated", "Rear in contact", "Stop isolated", "SAP",
#                         "WallJump","extra", "totalDistance"]
#     behavioralEvents = ["Fight","Gets to Fight","Won Fight","Lost Fight","extra", "totalDistance"]

    for file in files:
        print(file)
        connection = sqlite3.connect( file )
        profileData[file] = {}
    
        pool = AnimalPool( )
        pool.loadAnimals( connection )

        if nightComputation.lower() == "no":
#             print("no-1")
            minT = tmin
            maxT = tmax
            n = 0
            #Compute profile data and save them in a text file
            profileData[file][n] = computeProfile(file = file, minT=minT, maxT=maxT, night=n)
            text_file.write( "\n" )
            print("Profile data saved.")
            
        if nightComputation.lower() == "yes":
#             print("yes-1")
            nightEventTimeLine = EventTimeLineCached(connection, file, "night", minFrame=tmin, maxFrame=tmax )
            n = 1
            
            for eventNight in nightEventTimeLine.getEventList():
                minT = eventNight.startFrame
                maxT = eventNight.endFrame
                print("* * **   Night: ", n, "   ** * *")
                print(minT, maxT)
                #Compute profile data and save them in a text file
                profileData[file][n] = computeProfile(file=file, minT=minT, maxT=maxT, night=n)
                text_file.write( "\n" )
                print("-- Profile data saved. --")
                
                n+=1 #increase 'n' for the following nights
        else: #Neither 'yes' or 'no' for night computation
            print("There is a problem with your answer!")
            
        connection.close() #Close the connection with database (Saves memory?)

    text_file.write( "\n" )
    print("--- Write text before plotting ProfileData ---")    
    
    print('### Checking number of nights ###')
    nb_nights = {}
    for file in profileData:
        print(file)
        nb_nights[file]=len(profileData[file])
        print(len(profileData[file]))
    print(nb_nights)
    nb_max_nights = max(nb_nights.keys(), key=nb_nights.get)
    nb_min_nights = min(nb_nights.keys(), key=nb_nights.get)

    print(f'Maximum number of nights: {nb_nights[nb_max_nights]} in {nb_max_nights}')
    print(f'Minimum number of nights: {nb_nights[nb_min_nights]} in {nb_min_nights}')
    
    if nightComputation.lower() == "no":
#         print("no-2")
        n = 0

        #Plot profile data and save them in a png figure
        plotProfileDataDuration(profileData=profileData, night=n, 
                                valueCat=" TotalLen", text_file_name = text_file_name, nbNightsDic=None)
        plotProfileDataDuration(profileData=profileData, night=n, 
                                valueCat=" Nb", text_file_name = text_file_name, nbNightsDic=None)
        
        #Test profile data and save results in a text file
        text_file.write( "Statistical analysis: mixed linear models" )
        text_file.write( "{}\n" )
        testProfileData(profileData=profileData, night=n, eventListNames=behavioralEvents[:-2], 
                        valueCat=" TotalLen", text_file=text_file, nbNightsDic=None)
        testProfileData(profileData=profileData, night=n, eventListNames=behavioralEvents[:-2], 
                        valueCat=" Nb", text_file=text_file, nbNightsDic=None)
        print("test for total distance")
        testProfileData(profileData=profileData, night=n, eventListNames=["totalDistance"], 
                        valueCat="", text_file=text_file, nbNightsDic=None)
        
    if nightComputation.lower() == "yes":
        #Following line removed because 'nightEventTimeLine' is already computed before
#         nightEventTimeLine = EventTimeLineCached( connection, file, "night", minFrame=tmin, maxFrame=tmax )
        
        n = 1 #night counter
    
        for eventNight in nightEventTimeLine.getEventList():
            print("* * **  *** Night: ", n, " ***  ** * *")

            #Plot profile data and save them
            plotProfileDataDuration(profileData=profileData, night=n, valueCat=" TotalLen", 
                                    text_file_name = text_file_name, nbNightsDic=nb_nights)
            plotProfileDataDuration(profileData=profileData, night=n, valueCat=" Nb", 
                                    text_file_name = text_file_name, nbNightsDic=nb_nights)


#             plotProfileDataDuration(profileData=profileData, night=n, valueCat=" TotalLen")
#             plotProfileDataDuration(profileData=profileData, night=n, valueCat=" Nb")

            if doStats.lower() == "yes" :
                #Test profile data and save results in a text file
                print(" -- Now, doing some stats...")
                text_file.write( "Statistical analysis: mixed linear models" )
                text_file.write( "{}\n" )
                testProfileData(profileData=profileData, night=n, eventListNames=behavioralEvents[:-2], 
                                valueCat=" TotalLen", text_file=text_file, nbNightsDic=nb_nights)
                testProfileData(profileData=profileData, night=n, eventListNames=behavioralEvents[:-2], 
                                valueCat=" Nb", text_file=text_file, nbNightsDic=nb_nights)
                print("test for total distance")
                testProfileData(profileData=profileData, night=n, eventListNames=["totalDistance"], 
                                valueCat="", text_file=text_file, nbNightsDic=nb_nights)
            n+=1 #Implement the night counter
#             if n > nb_min_nights:
#                 print("Different number of nights in the databases provided, the computation stops here ...")

    print("") 
    print( "***************************************************")
    print ("Plots saved as png and analyses saved in text file.")
    text_file.close()

    print ("*** ALL JOBS DONE ***")
    # datetime object containing current date and time
    now = datetime.now()
    print("Ends @", now)
# Out:
# Code launched.
# Start @ 2022-12-06 11:59:50.387266
# Enter time information in frame. You can also set in days, hour, minutes
# valid entries are: 100, 1d, 1.5d, 23.5h, 1d 2h 3m 4s 5f
# Starting t :  0
# Entry (in frame) : 0
# Ending t :  115000
# Entry (in frame) : 115000
# Enter file name to save data (.txt will be added):  zefd
# Compute profile only during night events (Yes or No)?  No
# Do you want to do Stats on your data (Yes or No)? (Warning: MORE THAN ONE FILE REQUIRED):  No
# Is there a Genotype to exclude? (a 'keyword' or 'NO' if None) DON'T LEAVE BLANK!):
# Is there a Genotype to exclude? (a 'keyword' or 'NO' if None) DON'T LEAVE BLANK!):  No
# What's the MAX number of Animals per LMT ? (1,2,3 or 4):  3
# E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite
# Loading animals ...
# Fields available in lmtanalysis Z:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004849551 Genotype:NaCl User1:None
# Animal Id:2 Name:B RFID:000004849390 Genotype:NaCl User1:None
# Animal Id:3 Name:C RFID:000004849540 Genotype:NaCl User1:None
# Loading animals ...
# Fields available in lmtanalysis Z:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004849551 Genotype:NaCl User1:None
# Animal Id:2 Name:B RFID:000004849390 Genotype:NaCl User1:None
# Animal Id:3 Name:C RFID:000004849540 Genotype:NaCl User1:None
# computing individual animal:1
# RFID:000004849551
# computing individual event: Contact
# Contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 226  records loaded in  0.7250015735626221 S )
# Caching eventTimeLine
# total event duration:  10682
# Contact NaCl 1 10682 226
# computing individual event: Oral-oral Contact
# Oral-oral Contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 193  records loaded in  0.05701279640197754 S )
# Caching eventTimeLine
# total event duration:  1797
# Oral-oral Contact NaCl 1 1797 193
# computing individual event: Oral-genital Contact
# Oral-genital Contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 192  records loaded in  0.05401253700256348 S )
# Caching eventTimeLine
# total event duration:  1460
# Oral-genital Contact NaCl 1 1460 192
# computing individual event: Side by side Contact
# Side by side Contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 126  records loaded in  0.05400347709655762 S )
# Caching eventTimeLine
# total event duration:  1819
# Side by side Contact NaCl 1 1819 126
# computing individual event: Side by side Contact, opposite way
# Side by side Contact, opposite way  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 110  records loaded in  0.054012298583984375 S )
# Caching eventTimeLine
# total event duration:  1858
# Side by side Contact, opposite way NaCl 1 1858 110
# computing individual event: Social approach
# Social approach  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 2081  records loaded in  0.06401467323303223 S )
# Caching eventTimeLine
# total event duration:  6058
# Social approach NaCl 1 6058 2081
# computing individual event: Get away
# Get away  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 1137  records loaded in  0.0580134391784668 S )
# Caching eventTimeLine
# total event duration:  2754
# Get away NaCl 1 2754 1137
# computing individual event: Approach contact
# Approach contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 1227  records loaded in  0.05901312828063965 S )
# Caching eventTimeLine
# total event duration:  3772
# Approach contact NaCl 1 3772 1227
# computing individual event: Approach rear
# Approach rear  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 368  records loaded in  0.05601358413696289 S )
# Caching eventTimeLine
# total event duration:  1076
# Approach rear NaCl 1 1076 368
# computing individual event: Break contact
# Break contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 84  records loaded in  0.05301165580749512 S )
# Caching eventTimeLine
# total event duration:  749
# Break contact NaCl 1 749 84
# computing individual event: FollowZone Isolated
# FollowZone Isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 81  records loaded in  0.05401301383972168 S )
# Caching eventTimeLine
# total event duration:  163
# FollowZone Isolated NaCl 1 163 81
# computing individual event: Train2
# Train2  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 0  records loaded in  0.05201148986816406 S )
# Caching eventTimeLine
# total event duration:  0
# Train2 NaCl 1 0 0
# computing individual event: Group2
# Group2  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 222  records loaded in  0.056012630462646484 S )
# Caching eventTimeLine
# total event duration:  7136
# Group2 NaCl 1 7136 222
# computing individual event: Group3
# Group3  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 80  records loaded in  0.05501270294189453 S )
# Caching eventTimeLine
# total event duration:  3546
# Group3 NaCl 1 3546 80
# computing individual event: Group 3 break
# Group 3 break  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 42  records loaded in  0.05301213264465332 S )
# Caching eventTimeLine
# total event duration:  42
# Group 3 break NaCl 1 42 42
# computing individual event: Group 3 make
# Group 3 make  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 42  records loaded in  0.05301260948181152 S )
# Caching eventTimeLine
# total event duration:  42
# Group 3 make NaCl 1 42 42
# computing individual event: Move isolated
# Move isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 958  records loaded in  0.058012962341308594 S )
# Caching eventTimeLine
# total event duration:  3242
# Move isolated NaCl 1 3242 958
# computing individual event: Move in contact
# Move in contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 272  records loaded in  0.05601310729980469 S )
# Caching eventTimeLine
# total event duration:  993
# Move in contact NaCl 1 993 272
# computing individual event: Rear isolated
# Rear isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 198  records loaded in  0.05501294136047363 S )
# Caching eventTimeLine
# total event duration:  510
# Rear isolated NaCl 1 510 198
# computing individual event: SAP
# SAP  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 131  records loaded in  0.05401349067687988 S )
# Caching eventTimeLine
# total event duration:  1258
# SAP NaCl 1 1258 131
# computing individual event: Rear in contact
# Rear in contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 330  records loaded in  0.05601215362548828 S )
# Caching eventTimeLine
# total event duration:  999
# Rear in contact NaCl 1 999 330
# computing individual event: Stop isolated
# Stop isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 916  records loaded in  0.07701778411865234 S )
# Caching eventTimeLine
# total event duration:  52644
# Stop isolated NaCl 1 52644 916
# computing individual event: WallJump
# WallJump  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 15  records loaded in  0.05501198768615723 S )
# Caching eventTimeLine
# total event duration:  33
# WallJump NaCl 1 33 15
# computing individual animal:2
# RFID:000004849390
# computing individual event: Contact
# Contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 248  records loaded in  0.062014102935791016 S )
# Caching eventTimeLine
# total event duration:  14434
# Contact NaCl 2 14434 248
# computing individual event: Oral-oral Contact
# Oral-oral Contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 188  records loaded in  0.055013179779052734 S )
# Caching eventTimeLine
# total event duration:  1876
# Oral-oral Contact NaCl 2 1876 188
# computing individual event: Oral-genital Contact
# Oral-genital Contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 376  records loaded in  0.05701255798339844 S )
# Caching eventTimeLine
# total event duration:  2647
# Oral-genital Contact NaCl 2 2647 376
# computing individual event: Side by side Contact
# Side by side Contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 113  records loaded in  0.056012868881225586 S )
# Caching eventTimeLine
# total event duration:  1669
# Side by side Contact NaCl 2 1669 113
# computing individual event: Side by side Contact, opposite way
# Side by side Contact, opposite way  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 133  records loaded in  0.06001400947570801 S )
# Caching eventTimeLine
# total event duration:  1636
# Side by side Contact, opposite way NaCl 2 1636 133
# computing individual event: Social approach
# Social approach  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 2076  records loaded in  0.12202835083007812 S )
# Caching eventTimeLine
# total event duration:  5705
# Social approach NaCl 2 5705 2076
# computing individual event: Get away
# Get away  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 1083  records loaded in  0.05901288986206055 S )
# Caching eventTimeLine
# total event duration:  2662
# Get away NaCl 2 2662 1083
# computing individual event: Approach contact
# Approach contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 1505  records loaded in  0.061014413833618164 S )
# Caching eventTimeLine
# total event duration:  4193
# Approach contact NaCl 2 4193 1505
# computing individual event: Approach rear
# Approach rear  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 459  records loaded in  0.05601239204406738 S )
# Caching eventTimeLine
# total event duration:  1007
# Approach rear NaCl 2 1007 459
# computing individual event: Break contact
# Break contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 76  records loaded in  0.05501294136047363 S )
# Caching eventTimeLine
# total event duration:  600
# Break contact NaCl 2 600 76
# computing individual event: FollowZone Isolated
# FollowZone Isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 114  records loaded in  0.055013179779052734 S )
# Caching eventTimeLine
# total event duration:  209
# FollowZone Isolated NaCl 2 209 114
# computing individual event: Train2
# Train2  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 0  records loaded in  0.05301165580749512 S )
# Caching eventTimeLine
# total event duration:  0
# Train2 NaCl 2 0 0
# computing individual event: Group2
# Group2  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 291  records loaded in  0.058013916015625 S )
# Caching eventTimeLine
# total event duration:  10888
# Group2 NaCl 2 10888 291
# computing individual event: Group3
# Group3  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 80  records loaded in  0.05501294136047363 S )
# Caching eventTimeLine
# total event duration:  3546
# Group3 NaCl 2 3546 80
# computing individual event: Group 3 break
# Group 3 break  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 23  records loaded in  0.05401158332824707 S )
# Caching eventTimeLine
# total event duration:  23
# Group 3 break NaCl 2 23 23
# computing individual event: Group 3 make
# Group 3 make  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 14  records loaded in  0.05301237106323242 S )
# Caching eventTimeLine
# total event duration:  14
# Group 3 make NaCl 2 14 14
# computing individual event: Move isolated
# Move isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 445  records loaded in  0.0560145378112793 S )
# Caching eventTimeLine
# total event duration:  2368
# Move isolated NaCl 2 2368 445
# computing individual event: Move in contact
# Move in contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 289  records loaded in  0.06501340866088867 S )
# Caching eventTimeLine
# total event duration:  1110
# Move in contact NaCl 2 1110 289
# computing individual event: Rear isolated
# Rear isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 324  records loaded in  0.05501294136047363 S )
# Caching eventTimeLine
# total event duration:  797
# Rear isolated NaCl 2 797 324
# computing individual event: SAP
# SAP  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 142  records loaded in  0.054012298583984375 S )
# Caching eventTimeLine
# total event duration:  738
# SAP NaCl 2 738 142
# computing individual event: Rear in contact
# Rear in contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 267  records loaded in  0.05501246452331543 S )
# Caching eventTimeLine
# total event duration:  922
# Rear in contact NaCl 2 922 267
# computing individual event: Stop isolated
# Stop isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 499  records loaded in  0.06801581382751465 S )
# Caching eventTimeLine
# total event duration:  35267
# Stop isolated NaCl 2 35267 499
# computing individual event: WallJump
# WallJump  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 20  records loaded in  0.054012298583984375 S )
# Caching eventTimeLine
# total event duration:  42
# WallJump NaCl 2 42 20
# computing individual animal:3
# RFID:000004849540
# computing individual event: Contact
# Contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 221  records loaded in  0.05901384353637695 S )
# Caching eventTimeLine
# total event duration:  12518
# Contact NaCl 3 12518 221
# computing individual event: Oral-oral Contact
# Oral-oral Contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 186  records loaded in  0.05501246452331543 S )
# Caching eventTimeLine
# total event duration:  1426
# Oral-oral Contact NaCl 3 1426 186
# computing individual event: Oral-genital Contact
# Oral-genital Contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 219  records loaded in  0.05501294136047363 S )
# Caching eventTimeLine
# total event duration:  1527
# Oral-genital Contact NaCl 3 1527 219
# computing individual event: Side by side Contact
# Side by side Contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 118  records loaded in  0.05501246452331543 S )
# Caching eventTimeLine
# total event duration:  1605
# Side by side Contact NaCl 3 1605 118
# computing individual event: Side by side Contact, opposite way
# Side by side Contact, opposite way  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 128  records loaded in  0.05501294136047363 S )
# Caching eventTimeLine
# total event duration:  1651
# Side by side Contact, opposite way NaCl 3 1651 128
# computing individual event: Social approach
# Social approach  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 1808  records loaded in  0.06301426887512207 S )
# Caching eventTimeLine
# total event duration:  4950
# Social approach NaCl 3 4950 1808
# computing individual event: Get away
# Get away  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 1001  records loaded in  0.060013532638549805 S )
# Caching eventTimeLine
# total event duration:  2178
# Get away NaCl 3 2178 1001
# computing individual event: Approach contact
# Approach contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 1201  records loaded in  0.05901360511779785 S )
# Caching eventTimeLine
# total event duration:  3047
# Approach contact NaCl 3 3047 1201
# computing individual event: Approach rear
# Approach rear  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 334  records loaded in  0.05501270294189453 S )
# Caching eventTimeLine
# total event duration:  873
# Approach rear NaCl 3 873 334
# computing individual event: Break contact
# Break contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 77  records loaded in  0.05401206016540527 S )
# Caching eventTimeLine
# total event duration:  501
# Break contact NaCl 3 501 77
# computing individual event: FollowZone Isolated
# FollowZone Isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 88  records loaded in  0.05401253700256348 S )
# Caching eventTimeLine
# total event duration:  181
# FollowZone Isolated NaCl 3 181 88
# computing individual event: Train2
# Train2  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 0  records loaded in  0.053012847900390625 S )
# Caching eventTimeLine
# total event duration:  0
# Train2 NaCl 3 0 0
# computing individual event: Group2
# Group2  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 244  records loaded in  0.0580136775970459 S )
# Caching eventTimeLine
# total event duration:  8972
# Group2 NaCl 3 8972 244
# computing individual event: Group3
# Group3  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 80  records loaded in  0.057012319564819336 S )
# Caching eventTimeLine
# total event duration:  3546
# Group3 NaCl 3 3546 80
# computing individual event: Group 3 break
# Group 3 break  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 29  records loaded in  0.05401301383972168 S )
# Caching eventTimeLine
# total event duration:  29
# Group 3 break NaCl 3 29 29
# computing individual event: Group 3 make
# Group 3 make  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 28  records loaded in  0.05401182174682617 S )
# Caching eventTimeLine
# total event duration:  28
# Group 3 make NaCl 3 28 28
# computing individual event: Move isolated
# Move isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 501  records loaded in  0.05701422691345215 S )
# Caching eventTimeLine
# total event duration:  2233
# Move isolated NaCl 3 2233 501
# computing individual event: Move in contact
# Move in contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 271  records loaded in  0.05601239204406738 S )
# Caching eventTimeLine
# total event duration:  1083
# Move in contact NaCl 3 1083 271
# computing individual event: Rear isolated
# Rear isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 53  records loaded in  0.05401253700256348 S )
# Caching eventTimeLine
# total event duration:  144
# Rear isolated NaCl 3 144 53
# computing individual event: SAP
# SAP  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 315  records loaded in  0.05701255798339844 S )
# Caching eventTimeLine
# total event duration:  3133
# SAP NaCl 3 3133 315
# computing individual event: Rear in contact
# Rear in contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 137  records loaded in  0.05401253700256348 S )
# Caching eventTimeLine
# total event duration:  492
# Rear in contact NaCl 3 492 137
# computing individual event: Stop isolated
# Stop isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 463  records loaded in  0.07201743125915527 S )
# Caching eventTimeLine
# total event duration:  43481
# Stop isolated NaCl 3 43481 463
# computing individual event: WallJump
# WallJump  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 115000 ) Loaded ( 13  records loaded in  0.05501270294189453 S )
# Caching eventTimeLine
# total event duration:  28
# WallJump NaCl 3 28 13
# Animal Id:1 Name:A RFID:000004849551 Genotype:NaCl User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=115000
# Animal Id:1 Name:A RFID:000004849551 Genotype:NaCl User1:None   66568  detections loaded in 1.524876594543457 seconds.
# Compute total distance min:0 max:115000
# Animal Id:2 Name:B RFID:000004849390 Genotype:NaCl User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=115000
# Animal Id:2 Name:B RFID:000004849390 Genotype:NaCl User1:None   52069  detections loaded in 1.4062590599060059 seconds.
# Compute total distance min:0 max:115000
# Animal Id:3 Name:C RFID:000004849540 Genotype:NaCl User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=115000
# Animal Id:3 Name:C RFID:000004849540 Genotype:NaCl User1:None   58232  detections loaded in 1.6209962368011475 seconds.
# Compute total distance min:0 max:115000
# Profile data saved.
# There is a problem with your answer!
# --- Write text before plotting ProfileData ---
# ### Checking number of nights ###
# E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite
# 1
# {'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite': 1}
# Maximum number of nights: 1 in E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite
# Minimum number of nights: 1 in E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite
# event:  Contact TotalLen
# y:  [10682, 14434, 12518]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Oral-oral Contact TotalLen
# y:  [1797, 1876, 1426]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Oral-genital Contact TotalLen
# y:  [1460, 2647, 1527]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Side by side Contact TotalLen
# y:  [1819, 1669, 1605]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Side by side Contact, opposite way TotalLen
# y:  [1858, 1636, 1651]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Social approach TotalLen
# y:  [6058, 5705, 4950]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Get away TotalLen
# y:  [2754, 2662, 2178]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Approach contact TotalLen
# y:  [3772, 4193, 3047]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Approach rear TotalLen
# y:  [1076, 1007, 873]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Break contact TotalLen
# y:  [749, 600, 501]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  FollowZone Isolated TotalLen
# y:  [163, 209, 181]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Train2 TotalLen
# y:  [0, 0, 0]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Group2 TotalLen
# y:  [7136, 10888, 8972]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Group3 TotalLen
# y:  [3546, 3546, 3546]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Group 3 break TotalLen
# y:  [42, 23, 29]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Group 3 make TotalLen
# y:  [42, 14, 28]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Move isolated TotalLen
# y:  [3242, 2368, 2233]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Move in contact TotalLen
# y:  [993, 1110, 1083]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Rear isolated TotalLen
# y:  [510, 797, 144]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  SAP TotalLen
# y:  [1258, 738, 3133]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Rear in contact TotalLen
# y:  [999, 922, 492]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Stop isolated TotalLen
# y:  [52644, 35267, 43481]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  WallJump TotalLen
# y:  [33, 42, 28]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# plot Total Distance
# y:  [83.45897276604113, 52.53039039823052, 51.248485983248685]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\uid-1323\AppData\Local\Temp\ipykernel_4252\3805115011.py:161: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[row,col].set_ylim(min(y)-0.2*max(y), max(y)+0.2*max(y))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Saving  zefd.txt_ TotalLen_night_0.png
# event:  Contact Nb
# y:  [226, 248, 221]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Oral-oral Contact Nb
# y:  [193, 188, 186]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Oral-genital Contact Nb
# y:  [192, 376, 219]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Side by side Contact Nb
# y:  [126, 113, 118]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Side by side Contact, opposite way Nb
# y:  [110, 133, 128]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Social approach Nb
# y:  [2081, 2076, 1808]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Get away Nb
# y:  [1137, 1083, 1001]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Approach contact Nb
# y:  [1227, 1505, 1201]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Approach rear Nb
# y:  [368, 459, 334]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Break contact Nb
# y:  [84, 76, 77]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  FollowZone Isolated Nb
# y:  [81, 114, 88]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Train2 Nb
# y:  [0, 0, 0]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Group2 Nb
# y:  [222, 291, 244]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Group3 Nb
# y:  [80, 80, 80]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Group 3 break Nb
# y:  [42, 23, 29]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Group 3 make Nb
# y:  [42, 14, 28]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Move isolated Nb
# y:  [958, 445, 501]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Move in contact Nb
# y:  [272, 289, 271]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Rear isolated Nb
# y:  [198, 324, 53]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  SAP Nb
# y:  [131, 142, 315]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Rear in contact Nb
# y:  [330, 267, 137]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  Stop isolated Nb
# y:  [916, 499, 463]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# event:  WallJump Nb
# y:  [15, 20, 13]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# plot Total Distance
# y:  [83.45897276604113, 52.53039039823052, 51.248485983248685]
# x:  ['NaCl', 'NaCl', 'NaCl']
# group:  ['E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite', 'E:/LMT + Amphetamine/LMT recordings (DBs rebuilt)/221021_Amphet_Cage2_weekend2.sqlite']
# Nb of experiments:  1
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\uid-1323\AppData\Local\Temp\ipykernel_4252\3805115011.py:161: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[row,col].set_ylim(min(y)-0.2*max(y), max(y)+0.2*max(y))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Saving  zefd.txt_ Nb_night_0.png
# event:  Contact TotalLen
#           Mixed Linear Model Regression Results
# ==========================================================
# Model:            MixedLM Dependent Variable: value
# No. Observations: 3       Method:             REML
# No. Groups:       1       Scale:              3519909.3333
# Min. group size:  3       Log-Likelihood:     -18.4611
# Max. group size:  3       Converged:          Yes
# Mean group size:  3.0
# ----------------------------------------------------------
#              Coef.    Std.Err. z P>|z|   [0.025    0.975]
# ----------------------------------------------------------
# Intercept   12544.667    0.000   0.000 12544.667 12544.667
# Group Var 3519909.333
# ==========================================================
#
# event:  Oral-oral Contact TotalLen
#               Mixed Linear Model Regression Results
# ==================================================================
# Model:                MixedLM    Dependent Variable:    value
# No. Observations:     3          Method:                REML
# No. Groups:           1          Scale:                 57730.3333
# Min. group size:      3          Log-Likelihood:        -14.3507
# Max. group size:      3          Converged:             Yes
# Mean group size:      3.0
# ------------------------------------------------------------------
#             Coef.   Std.Err.       z       P>|z|  [0.025   0.975]
# ------------------------------------------------------------------
# Intercept  1699.667    0.000 581416351.459 0.000 1699.667 1699.667
# Group Var 57730.333
# ==================================================================
#
# event:  Oral-genital Contact TotalLen
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2708: RuntimeWarning: divide by zero encountered in divide
#   sdf[0:self.k_fe, 2] = sdf[0:self.k_fe, 0] / sdf[0:self.k_fe, 1]
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2708: RuntimeWarning: divide by zero encountered in divide
#   sdf[0:self.k_fe, 2] = sdf[0:self.k_fe, 0] / sdf[0:self.k_fe, 1]
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4252\3805115011.py in <module>
#     359         text_file.write( "Statistical analysis: mixed linear models" )
#     360         text_file.write( "{}\n" )
# --> 361         testProfileData(profileData=profileData, night=n, eventListNames=behavioralEvents[:-2],
#     362                         valueCat=" TotalLen", text_file=text_file, nbNightsDic=None)
#     363         testProfileData(profileData=profileData, night=n, eventListNames=behavioralEvents[:-2],
#
# ~\AppData\Local\Temp\ipykernel_4252\3805115011.py in testProfileData(profileData, night, eventListNames, valueCat, text_file, nbNightsDic)
#     235         #Mixed model: variable to explain: value; fixed factor = genotype; random effect: group
#     236         model = smf.mixedlm("value ~ genotype", dfData, groups = dfData["group"])  #Creates the model
# --> 237         result = model.fit()  #Run model
#     238         print(result.summary())  #Print summary
#     239         text_file.write(result.summary().as_text())
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\mixed_linear_model.py in fit(self, start_params, reml, niter_sa, do_cg, fe_pen, cov_pen, free, full_output, method, **fit_kwargs)
#    2255                 pcov[np.ix_(ii, ii)] = np.linalg.inv(-hess1)
#    2256         else:
# -> 2257             pcov = np.linalg.inv(-hess)
#    2258         if np.any(hess_diag >= 0):
#    2259             msg = ("The Hessian matrix at the estimated parameter values " +
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\overrides.py in inv(*args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in inv(a)
#     550     signature = 'D->D' if isComplexType(t) else 'd->d'
#     551     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 552     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     553     return wrap(ainv.astype(result_t, copy=False))
#     554
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_singular(err, flag)
#      87
#      88 def _raise_linalgerror_singular(err, flag):
# ---> 89     raise LinAlgError("Singular matrix")
#      90
#      91 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
