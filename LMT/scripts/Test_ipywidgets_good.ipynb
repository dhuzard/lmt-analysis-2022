# %%
pip install cufflinks
pip install ipywidgets
pip install chart_studio
# Out:
# Requirement already satisfied: chart_studio in c:\users\paulc\appdata\local\programs\python\python310\lib\site-packages (1.1.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: retrying>=1.3.3 in c:\users\paulc\appdata\local\programs\python\python310\lib\site-packages (from chart_studio) (1.3.4)
# Requirement already satisfied: plotly in c:\users\paulc\appdata\local\programs\python\python310\lib\site-packages (from chart_studio) (5.11.0)
# Requirement already satisfied: requests in c:\users\paulc\appdata\local\programs\python\python310\lib\site-packages (from chart_studio) (2.28.1)
# Requirement already satisfied: six in c:\users\paulc\appdata\local\programs\python\python310\lib\site-packages (from chart_studio) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\paulc\appdata\local\programs\python\python310\lib\site-packages (from plotly->chart_studio) (8.1.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\paulc\appdata\local\programs\python\python310\lib\site-packages (from requests->chart_studio) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\paulc\appdata\local\programs\python\python310\lib\site-packages (from requests->chart_studio) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\paulc\appdata\local\programs\python\python310\lib\site-packages (from requests->chart_studio) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\paulc\appdata\local\programs\python\python310\lib\site-packages (from requests->chart_studio) (1.26.12)

# %%
ipywidgets.version__info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 ipywidgets.version__info
#
# NameError: name 'ipywidgets' is not defined

# %%
# %matplotlib tk

# %%
import ipywidgets as widgets
from ipywidgets import *
from ipywidgets import interactive
from ipywidgets import interact
from ipywidgets import HBox, VBox
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
import csv
import cufflinks as cf
import itertools

# Read csv
df = pd.read_csv("C:/Users/paulc/Desktop/Stage/lmt-analysis-2022/LMT/scripts/Dataframes/Merge.csv")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102537 entries, 0 to 102536
# Data columns (total 29 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      102537 non-null  int64
#  1   Filename        102537 non-null  object
#  2   Date            102537 non-null  int64
#  3   Cage            102537 non-null  object
#  4   Injection       102537 non-null  object
#  5   Night-Phase     102537 non-null  int64
#  6   Bin             102537 non-null  int64
#  7   start_frame     102537 non-null  int64
#  8   stop_frame      102537 non-null  int64
#  9   name            102537 non-null  object
#  10  idA             102537 non-null  int64
#  11  idB             77994 non-null   float64
#  12  idC             4998 non-null    float64
#  13  idD             0 non-null       float64
#  14  RFidA           102537 non-null  int64
#  15  RFidB           101169 non-null  float64
#  16  RFidC           92799 non-null   float64
#  17  RFidD           0 non-null       float64
#  18  GenoA           95400 non-null   object
#  19  GenoB           94086 non-null   object
#  20  GenoC           85884 non-null   object
#  21  GenoD           0 non-null       float64
#  22  totalLength     102537 non-null  int64
#  23  meanLength      72989 non-null   float64
#  24  medianLength    0 non-null       float64
#  25  numberOfEvents  102537 non-null  int64
#  26  stdLength       72989 non-null   float64
#  27  CI95_low        72989 non-null   float64
#  28  CI95_up         72989 non-null   float64
# dtypes: float64(12), int64(10), object(7)
# memory usage: 22.7+ MB
# None
# C:\Users\paulc\AppData\Local\Temp\ipykernel_11244\820973489.py:17: DtypeWarning:
#
# Columns (18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
# import ipywidgets as widgets
# from ipywidgets import interactive
# from ipywidgets import interact
# import matplotlib
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# import seaborn as sns
# import os
# import csv
# import cufflinks as cf

# # Read csv
# df = pd.read_csv("C:/Users/paulc/Desktop/Stage/lmt-analysis-2022/LMT/scripts/Dataframes/Merge.csv")

# date = df["Date"].unique()
# cage = df["Cage"].unique()
# night_phase = df["Night-Phase"].unique()
# bins = df["Bin"].unique()
# event = df["name"].unique()

# drop1 = widgets.Dropdown(options=date, value=221013, description='Date:', disabled=False)
# drop2 = widgets.Dropdown(options=cage, value='Cage1', description='Cage:', disabled=False)
# drop3 = widgets.Dropdown(options=event, value='Move', description='Event:', disabled=False)
# drop4 = widgets.Dropdown(options=night_phase, value=1, description='Night_Phase:', disabled=False)

# def on_change(change):
#     drop2.options = df['Cage'][df['Date'] == drop1.value].unique()
#     drop4.options = df['Night-Phase'][df['Date'] == drop1.value].unique()

# drop1.observe(on_change)

# def update_temp_df(change):
#     # Mise à jour de temp_df en fonction de la sélection actuelle des widgets
#     global temp_df
#     temp_df = df[(df["Date"] == drop1.value) & (df["Cage"] == drop2.value) & (df["name"] == drop3.value) & (df["Night-Phase"] == drop4.value)]

# # Initialisation de temp_df en fonction de la sélection initiale des widgets
# temp_df = df[(df["Date"] == drop1.value) & (df["Cage"] == drop2.value) & (df["name"] == drop3.value) & (df["Night-Phase"] == drop4.value)]

# # Observation des widgets pour mettre à jour temp_df lorsque la sélection est modifiée
# drop1.observe(update_temp_df, 'value')
# drop2.observe(update_temp_df, 'value')
# drop3.observe(update_temp_df, 'value')
# drop4.observe(update_temp_df, 'value')

# # Préparation pour le tracé
# bins = temp_df['Bin'].unique()
# animals = temp_df['RFidA'].unique()
# nbrAnimals = len(animals)
# nbrEvents = {}

# def update_dropdown(date, cage, night_phase, event):
#     info = f"La date choisie est le {date}, il s'agit de la {cage.lower()} pour l'évènement '{event.lower()}' durant la phase {night_phase} de nuit !"
#     display(info)
#     plt.figure()
#     x=temp_df[temp_df.RFidA.isin(temp_df.RFidA.unique())]['Bin']
#     y=temp_df[temp_df.RFidA.isin(temp_df.RFidA.unique())]["numberOfEvents"]
#     sns.lineplot(temp_df,y=y,x=x,hue="GenoA", style='RFidA')
#     plt.title(f'Numbers of {drop3.value} per bin of each mouse') 
#     plt.ylabel(f'Numbers of {drop3.value}')
#     plt.legend(loc = "upper left")
#     plt.show()
    
# adapt_plot = interact(update_dropdown, date=drop1, cage=drop2, event=drop3, night_phase=drop4)
# adapt_plot
# Out:
# C:\Users\paulc\AppData\Local\Temp\ipykernel_18924\3616514618.py:14: DtypeWarning:
#
# Columns (18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
# interactive(children=(Dropdown(description='Date:', options=(221013, 221017, 221018, 221019, 221020, 221021, 2…
# <function __main__.update_dropdown(date, cage, night_phase, event)>

# %%
import ipywidgets as widgets
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
# %matplotlib inline

@widgets.interact(x=(0, 5))
def f(x=5):
    print(x)
    
@widgets.interact_manual(
    color=['blue', 'red', 'green'], lw=(1., 10.))
def plot(freq=1., color='blue', lw=2, grid=True):
    t = np.linspace(-1., +1., 1000)
    fig, ax = plt.subplots(1, 1, figsize=(8, 6))
    ax.plot(t, np.sin(2 * np.pi * freq * t),
            lw=lw, color=color)
    ax.grid(grid)

freq_slider = widgets.FloatSlider(
    value=2.,
    min=1.,
    max=10.0,
    step=0.1,
    description='Frequency:',
    readout_format='.1f',
)

range_slider = widgets.FloatRangeSlider(
    value=[-1., +1.],
    min=-5., max=+5., step=0.1,
    description='xlim:',
    readout_format='.1f',
)

grid_button = widgets.ToggleButton(
    value=False,
    description='Grid',
    icon='check'
)

color_buttons = widgets.ToggleButtons(
    options=['blue', 'red', 'green'],
    description='Color:',
)

title_textbox = widgets.Text(
    value='Hello World',
    description='Title:',
)

color_picker = widgets.ColorPicker(
    concise=True,
    description='Background color:',
    value='#efefef',
)

button = widgets.Button(
    description='Plot',
)

def plot2(b=None):
    xlim = range_slider.value
    freq = freq_slider.value
    grid = grid_button.value
    color = color_buttons.value
    title = title_textbox.value
    bgcolor = color_picker.value

    t = np.linspace(xlim[0], xlim[1], 1000)
    f, ax = plt.subplots(1, 1, figsize=(8, 6))
    ax.plot(t, np.sin(2 * np.pi * freq * t),
            color=color)
    ax.grid(grid)
    plt.show()
    
@button.on_click
def plot_on_click(b):
    plot2()
    
tab1 = VBox(children=[freq_slider,
                      range_slider,])
tab2 = VBox(children=[color_buttons,
                      HBox(children=[title_textbox,
                                     color_picker,
                                     grid_button]),
                                     ])
tab = widgets.Tab(children=[tab1, tab2])
tab.set_title(0, 'plot')
tab.set_title(1, 'styling')
VBox(children=[tab, button])
# Out:
# interactive(children=(IntSlider(value=5, description='x', max=5), Output()), _dom_classes=('widget-interact',)…
# interactive(children=(FloatSlider(value=1.0, description='freq', max=3.0, min=-1.0), Dropdown(description='col…
# VBox(children=(Tab(children=(VBox(children=(FloatSlider(value=2.0, description='Frequency:', max=10.0, min=1.0…

# %%
# NE PAS TOUCHER!!

from IPython.display import Markdown
import ipywidgets as widgets
from ipywidgets import *
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
import csv
import cufflinks as cf
import itertools
import scipy
from IPython.display import clear_output
# %matplotlib tk

# Read csv
os.chdir("C:/Users/paulc/Desktop/Stage/lmt-analysis-2022/LMT/scripts/Dataframes/")
df = pd.read_csv("Merge.csv")

date = df["Date"].unique()
cage = df["Cage"].unique()
night_phase = df["Night-Phase"].unique()
bins = df["Bin"].unique()
event = df["name"].unique()

reset_button = widgets.Button(description='Reset')
update_button = widgets.Button(description='Update')
drop1 = widgets.SelectMultiple(options=date, rows=5, description='Date', disabled=False)
# drop1 = widgets.Dropdown(options=date, value=221013, description='Date:', disabled=False)
drop2 = widgets.SelectMultiple(options=cage, rows=5, description='Cage', disabled=False)
# drop2 = widgets.Dropdown(options=cage, value='Cage1', description='Cage:', disabled=False)
# drop3 = widgets.SelectMultiple(options=event, value=['Move'], rows=5, description='Event', disabled=False)
drop3 = widgets.Dropdown(options=event, value=event[1], description='Event:', disabled=False)
drop4 = widgets.SelectMultiple(options=night_phase, rows=5, description='Night_Phase', disabled=False, value=[night_phase[0]])
# drop4 = widgets.Dropdown(options=night_phase, value=1, description='Night_Phase:', disabled=False)

update_button.on_click(lambda b: update_options(None))

box = HBox([reset_button, update_button, drop1, drop2, drop4, drop3])

# On crée l'onglet pour les widgets
tab = widgets.Tab(children=[box])
tab.set_title(0, 'Widgets')

# On affiche l'onglet
display(tab)

# Test1

# def on_change_cage(change):
#     options = df['Date'][df['Cage'] == drop2.value].unique()
#     drop1.options = options
#     drop1.value = list(set(drop1.value) & set(options))

# drop2.observe(on_change_cage)

# def on_change_date(change):
#     options = df['Cage'][df['Date'].isin(drop1.value)].unique()
#     drop2.options = options
#     drop2.value = list(set(drop2.value) & set(options))

# drop1.observe(on_change_date)

# Test2

# first_call = True

# def on_change_date(change):
#     global first_call
#     drop2.options = df['Cage'][df['Date'] == drop1.value].unique()
#     drop4.options = df['Night-Phase'][df['Date'] == drop1.value].unique()
#     first_call = True

# drop1.observe(on_change_date)

# def on_change_cage(change):
#     global first_call
#     if first_call:
#         drop1.options = df['Date'][df['Cage'] == drop2.value].unique()
#         first_call = False
#     else:
#         drop1.value = ()
#         drop1.options = df['Date'][df['Cage'] == drop2.value].unique()

# drop2.observe(on_change_cage)

# def on_change(change):
#     drop2.options = df['Cage'][df['Date'] == drop1.value].unique()
#     drop4.options = df['Night-Phase'][df['Date'] == drop1.value].unique()
#     # drop1.options = df['Date'][df['Cage'] == drop2.value].unique()

# drop1.observe(on_change)
# # drop2.observe(on_change)

def reset_selections(b):
    drop1.value = ()
    drop2.options = df['Cage'].unique()
    drop4.options = df['Night-Phase'].unique()

reset_button.on_click(reset_selections)

# Pour sélectionner plusieurs Dates
def update_options(change):
    # Filtrer les données du DataFrame en fonction des valeurs sélectionnées dans drop1
    filtered_df = df[df['Date'].isin(drop1.value)]
    
    # Mettre à jour les options de drop2 avec les valeurs uniques de la colonne "Cage" pour les données filtrées
    options = filtered_df['Cage'].unique()
    drop2.options = options
    
    # Conserver les valeurs sélectionnées dans drop2 si elles sont encore valides après la mise à jour des options
    drop2.value = list(set(drop2.value) & set(options))
    
    # Mettre à jour les options de drop4 avec les valeurs uniques de la colonne "Night-Phase" pour les données filtrées
    options = filtered_df['Night-Phase'].unique()
    drop4.options = options
    
    # Conserver les valeurs sélectionnées dans drop4 si elles sont encore valides après la mise à jour des options
    drop4.value = list(set(drop4.value) & set(options))

# Assigner la fonction update_options à l'événement "observe" de drop1
drop1.observe(update_options, names='value')

def update_temp_df(change):
    # Mise à jour de temp_df en fonction de la sélection actuelle des widgets
    global temp_df
    temp_df = df[(df["Date"].isin((drop1.value))) & (df["Cage"].isin((drop2.value))) & (df["name"] == drop3.value) & (df["Night-Phase"].isin((drop4.value)))]

# Initialisation de temp_df en fonction de la sélection initiale des widgets
temp_df = df[(df["Date"].isin((drop1.value))) & (df["Cage"].isin((drop2.value))) & (df["name"] == drop3.value) & (df["Night-Phase"].isin((drop4.value)))]

# Observation des widgets pour mettre à jour temp_df lorsque la sélection est modifiée
drop1.observe(update_temp_df, 'value')
drop2.observe(update_temp_df, 'value')
drop3.observe(update_temp_df, 'value')
drop4.observe(update_temp_df, 'value')

# Préparation pour le tracé
bins = temp_df['Bin'].unique()
animals = temp_df['RFidA'].unique()
nbrAnimals = len(animals)
nbrEvents = {}

# def update_dropdown(Date, Cage, Night_Phase, Event):
#     clear_output()
#     # info = f"La date choisie est le {date_val}, il s'agit de la {cage_val.lower()} pour l'évènement '{drop3.value}' durant la phase {night_phase_val} de nuit !"
#     display(Markdown(f"<h3>La date choisie est le {Date[0]}, il s'agit de la {Cage[0]} pour l'évènement '{Event}' durant la phase {Night_Phase[0]} de nuit !</h3>"))
#     global temp_df_loop
#     temp_df_loop = df[(df["Date"].isin(Date)) & (df["Cage"].isin(Cage)) & (df["name"].isin([Event])) & (df["Night-Phase"].isin(Night_Phase))]
#     # plt.figure(figsize=(18, 6))
#     # fig, (line_ax, bar_ax) = plt.subplots(1, 2, figsize=(20,5))
#     # fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6), width_ratios=[1, 1])
#     fig, ax1 = plt.subplots(figsize=(12,6))
#     ax2 = fig.add_axes([1, 0.25, 0.25, 0.5])
#     # x=temp_df_loop[temp_df_loop.RFidA.isin(temp_df_loop.RFidA.unique())]['Bin']
#     # y=temp_df_loop[temp_df_loop.RFidA.isin(temp_df_loop.RFidA.unique())]["numberOfEvents"]
#     sns.lineplot(temp_df_loop, y='numberOfEvents', x='Bin', hue="GenoA", style='RFidA', palette={'Amphet':'red', 'NaCl':'blue'}, ax=ax1)
#     ax1.set_title(f'Numbers of {drop3.value} per bin of each mouse')
#     ax1.set_ylabel(f'Numbers of {drop3.value}')
#     sns.barplot(data=temp_df_loop, y='numberOfEvents', x="GenoA", palette={'Amphet':'red', 'NaCl':'blue'}, ax=ax2)
#     ax2.set_title("A barplot")
#     plt.show()
#     mean_AMPHET = temp_df_loop[temp_df_loop["GenoA"] == 'Amphet']["numberOfEvents"]
#     mean_NACL = temp_df_loop[temp_df_loop["GenoA"] == 'NaCl']["numberOfEvents"]
#     stat, pvalue = scipy.stats.ttest_ind(mean_NACL,mean_AMPHET)
#     display(Markdown(f"<h3>La statistique du t-test est de {stat} et la p-value est de {pvalue}</h3>"))

# Fonction pour afficher le plot en fonction des choix de l'utilisateur
def update_dropdown(date, cage, night_phase, event):
    clear_output()
    for date_val, cage_val, night_phase_val in itertools.product(date, cage, night_phase):
        # info = f"La date choisie est le {date_val}, il s'agit de la {cage_val.lower()} pour l'évènement '{drop3.value}' durant la phase {night_phase_val} de nuit !"
        display(Markdown(f"<h3>La date choisie est le {date_val}, il s'agit de la {cage_val} pour l'évènement '{drop3.value}' durant la phase {night_phase_val} de nuit !</h3>"))
        global temp_df_loop
        temp_df_loop = df[(df["Date"] == date_val) & (df["Cage"] == cage_val) & (df["name"] == drop3.value) & (df["Night-Phase"] == night_phase_val)]
        # plt.figure(figsize=(18, 6))
        # fig, (line_ax, bar_ax) = plt.subplots(1, 2, figsize=(20,5))
        # fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6), width_ratios=[1, 1])
        fig, ax1 = plt.subplots(figsize=(12,6))
        ax2 = fig.add_axes([1, 0.25, 0.25, 0.5])
        # x=temp_df_loop[temp_df_loop.RFidA.isin(temp_df_loop.RFidA.unique())]['Bin']
        # y=temp_df_loop[temp_df_loop.RFidA.isin(temp_df_loop.RFidA.unique())]["numberOfEvents"]
        sns.lineplot(temp_df_loop, y='numberOfEvents', x='Bin', hue="GenoA", style='RFidA', palette={'Amphet':'red', 'NaCl':'blue'}, ax=ax1)
        ax1.set_title(f'Numbers of {drop3.value} per bin of each mouse')
        ax1.set_ylabel(f'Numbers of {drop3.value}')
        sns.barplot(data=temp_df_loop, y='numberOfEvents', x="GenoA", palette={'Amphet':'red', 'NaCl':'blue'}, ax=ax2)
        ax2.set_title("A barplot")
        plt.show()
        mean_AMPHET = temp_df_loop[temp_df_loop["GenoA"] == 'Amphet']["numberOfEvents"]
        mean_NACL = temp_df_loop[temp_df_loop["GenoA"] == 'NaCl']["numberOfEvents"]
        stat, pvalue = scipy.stats.ttest_ind(mean_NACL,mean_AMPHET)
        display(Markdown(f"<h3>La statistique du t-test est de {stat} et la p-value est de {pvalue}</h3>"))

# # #interact function in isolation
# adapt_plot = interact(update_dropdown, date=drop1, cage=drop2, event=drop3, night_phase=drop4)
# # tab_nest.children = [VBox(children = adapt_plot.children)]
# # display(tab_nest)
# adapt_plot

interactive_plot = widgets.interactive_output(update_dropdown, {'date': drop1, 'cage': drop2, 'night_phase': drop4, 'event': drop3})
display(interactive_plot)

# Faire un on_change de Date quand on clique sur la Cage après avoir choisi la Date
# Out:
# C:\Users\paulc\AppData\Local\Temp\ipykernel_14572\3493682421.py:21: DtypeWarning:
#
# Columns (18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
# Tab(children=(HBox(children=(Button(description='Reset', style=ButtonStyle()), Button(description='Update', st…
# Output()

# %%
import ipywidgets as widgets
from ipywidgets import *
from ipywidgets import interactive
from ipywidgets import interact
from ipywidgets import HBox, VBox
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
import csv
import cufflinks as cf
import itertools
from IPython.display import clear_output

# Read csv
os.chdir("C:/Users/paulc/Desktop/Stage/lmt-analysis-2022/LMT/scripts/Dataframes/")
df = pd.read_csv("Merge.csv")

date = df["Date"].unique()
cage = df["Cage"].unique()
night_phase = df["Night-Phase"].unique()
bins = df["Bin"].unique()
event = df["name"].unique()

reset_button = widgets.Button(description='Reset')
update_button = widgets.Button(description='Update')
drop1 = widgets.SelectMultiple(options=date, rows=5, description='Date', disabled=False)
# drop1 = widgets.Dropdown(options=date, value=221013, description='Date:', disabled=False)
drop2 = widgets.SelectMultiple(options=cage, rows=5, description='Cage', disabled=False)
# drop2 = widgets.Dropdown(options=cage, value='Cage1', description='Cage:', disabled=False)
# drop3 = widgets.SelectMultiple(options=event, value=['Move'], rows=5, description='Event', disabled=False)
drop3 = widgets.Dropdown(options=event, value=event[0], description='Event:', disabled=False)
drop4 = widgets.SelectMultiple(options=night_phase, rows=5, description='Night_Phase', disabled=False)
# drop4 = widgets.Dropdown(options=night_phase, value=1, description='Night_Phase:', disabled=False)

update_button.on_click(lambda b: update_options(None))

box = HBox([reset_button, update_button, drop1, drop2, drop4, drop3])

# On crée l'onglet pour les widgets
tab = widgets.Tab(children=[box])
tab.set_title(0, 'Widgets')

# On affiche l'onglet
display(tab)

# Pour sélectionner plusieurs Dates
def update_options(change):
    # Filtrer les données du DataFrame en fonction des valeurs sélectionnées dans drop1
    filtered_df = df[df['Date'].isin(drop1.value)]
    
    # Mettre à jour les options de drop2 avec les valeurs uniques de la colonne "Cage" pour les données filtrées
    options = filtered_df['Cage'].unique()
    drop2.options = options
    
    # Conserver les valeurs sélectionnées dans drop2 si elles sont encore valides après la mise à jour des options
    drop2.value = list(set(drop2.value) & set(options))
    
    # Mettre à jour les options de drop4 avec les valeurs uniques de la colonne "Night-Phase" pour les données filtrées
    options = filtered_df['Night-Phase'].unique()
    drop4.options = options
    
    # Conserver les valeurs sélectionnées dans drop4 si elles sont encore valides après la mise à jour des options
    drop4.value = list(set(drop4.value) & set(options))
    filtered_df = df[df['Date'].isin(drop1.value)]

def on_change_date(change):
    if drop1.value:
        current_value = drop2.value
        if current_value:
            current_value = current_value[0]
        options = df['Cage'][df['Date'].isin(drop1.value)].unique()
        drop2.options = options
        if current_value in options:
            drop2.value = current_value
        else:
            drop2.value = ()

drop1.observe(on_change_date)

def on_change_cage1(change):
    if drop2.value:
        current_value = drop1.value
        if current_value:
            current_value = current_value[0]
        options = df['Date'][df['Cage'] == drop2.value[0]].unique()
        drop1.options = options
        drop1.value = list(set(current_value) & set(options))

drop2.observe(on_change_cage1)

def on_change_cage2(change):
    if drop4.value:
        current_value = drop1.value
        if current_value:
            current_value = current_value[0]
        options = df['Date'][df['Night-Phase'] == drop4.value[0]].unique()
        drop1.options = options
        drop1.value = list(set(current_value) & set(options))

drop4.observe(on_change_cage2)

# Bouton reset
def on_reset_button_clicked(b):
    drop1.options = date
    drop1.value = tuple()
    drop2.value = tuple()
    drop4.options = night_phase
    drop4.value = tuple()

reset_button.on_click(on_reset_button_clicked)

# # Create a container to hold the plots
# out = widgets.Output()

# def update_plots(change):
#     with out:
#         clear_output(wait=True)
#         for value in drop1.value:
#             df_value = df[(df["Date"] == value) & (df["Cage"].isin(drop2.value))]
#             # Create and display a plot for the selected value
#             # (replace this with your own plotting code)
#             sns.lineplot(temp_df_loop,y='numberOfEvents',x='Bin',hue="GenoA", style='RFidA')
#             plt.title(f'Numbers of {drop3.value} per bin of each mouse')
#             plt.ylabel(f'Numbers of {drop3.value}')
#             plt.show()

# # Attach the callback function to the 'value' trait of drop1 and drop2
# drop1.observe(update_plots, names='value')
# drop2.observe(update_plots, names='value')

# def update_options_drop1(change):
#     # Filtrer les données du DataFrame en fonction des valeurs sélectionnées dans drop2
#     filtered_df = df[df['Cage'].isin(drop2.value)]

#     # Mettre à jour les options de drop1 avec les valeurs uniques de la colonne "Date" pour les données filtrées
#     options = filtered_df['Date'].unique()
#     drop1.options = options

#     # Conserver les valeurs sélectionnées dans drop1 si elles sont encore valides après la mise à jour des options
#     drop1.value = list(set(drop1.value) & set(options))
#     if len(drop2.value)==0:
#         drop1.options = date
#         drop2.options = cage
#         drop4.options = night_phase
#         return

# def update_options_drop1(change):
#     if len(drop2.value)==0:
#         drop1.options = date
#         drop2.options = cage
#         drop4.options = night_phase
#     else:
#         # Filtrer les données du DataFrame en fonction des valeurs sélectionnées dans drop2
#         filtered_df2 = df[df['Cage'].isin(drop2.value)]

#         # Mettre à jour les options de drop1 avec les valeurs uniques de la colonne "Date" pour les données filtrées
#         options = filtered_df2['Date'].unique()
#         drop1.options = options

#         # Conserver les valeurs sélectionnées dans drop1 si elles sont encore valides après la mise à jour des options
#         drop1.value = list(set(drop1.value) & set(options))

#         # Mettre à jour les options de drop2 avec les valeurs uniques de la colonne "Cage" pour les données filtrées
#         options = filtered_df2['Cage'].unique()
#         drop2.options = options

#         # Conserver les valeurs sélectionnées dans drop2 si elles sont encore valides après la mise à jour des options
#         drop2.value = list(set(drop2.value) & set(options))

#         # Mettre à jour les options de drop4 avec les valeurs uniques de la colonne "Night-Phase" pour les données filtrées
#         options = filtered_df2['Night-Phase'].unique()
#         drop4.options = options
#         drop4.value = list(set(drop4.value) & set(options))

# # Assigner la fonction update_options à l'événement "observe" de drop1
# drop1.observe(update_options, names='value')

# # Assigner la fonction update_options_drop1 à l'événement "observe" de drop2 pour qu'elle soit appelée lorsque des options sont sélectionnées dans drop2
# drop2.observe(update_options_drop1, names='value')

def update_temp_df(change):
    # Mise à jour de temp_df en fonction de la sélection actuelle des widgets
    global temp_df
    temp_df = df[(df["Date"].isin((drop1.value))) & (df["Cage"].isin((drop2.value))) & (df["name"] == drop3.value) & (df["Night-Phase"].isin((drop4.value)))]

# Initialisation de temp_df en fonction de la sélection initiale des widgets
temp_df = df[(df["Date"].isin((drop1.value))) & (df["Cage"].isin((drop2.value))) & (df["name"] == drop3.value) & (df["Night-Phase"].isin((drop4.value)))]

# Observation des widgets pour mettre à jour temp_df lorsque la sélection est modifiée
drop1.observe(update_temp_df, 'value')
drop2.observe(update_temp_df, 'value')
drop3.observe(update_temp_df, 'value')
drop4.observe(update_temp_df, 'value')

# Préparation pour le tracé
bins = temp_df['Bin'].unique()
animals = temp_df['RFidA'].unique()
nbrAnimals = len(animals)
nbrEvents = {}

# def update_dropdown(date, cage, night_phase, event):
#     for date_val, cage_val, night_phase_val in itertools.product(date, cage, night_phase):
#         info = f"La date choisie est le {date_val}, il s'agit de la {cage_val.lower()} pour l'évènement '{drop3.value}' durant la phase {night_phase_val} de nuit !"
#         display(info)
#         temp_df_loop = df[(df["Date"] == date_val) & (df["Cage"] == cage_val) & (df["name"] == drop3.value) & (df["Night-Phase"] == night_phase_val)]
#         plt.figure()
#         # x=temp_df_loop[temp_df_loop.RFidA.isin(temp_df_loop.RFidA.unique())]['Bin']
#         # y=temp_df_loop[temp_df_loop.RFidA.isin(temp_df_loop.RFidA.unique())]["numberOfEvents"]
#         sns.lineplot(temp_df_loop,y='numberOfEvents',x='Bin',hue="GenoA", style='RFidA')
#         plt.title(f'Numbers of {drop3.value} per bin of each mouse')
#         plt.ylabel(f'Numbers of {drop3.value}')
#         plt.show()

# # Fonction pour afficher le plot en fonction des choix de l'utilisateur
# def update_dropdown(date, cage, night_phase, event):
#     for date_val, cage_val, night_phase_val in itertools.product(date, cage, night_phase):
#         info = f"La date choisie est le {date_val}, il s'agit de la {cage_val.lower()} pour l'évènement '{drop3.value}' durant la phase {night_phase_val} de nuit !"
#         display(info)
#         temp_df_loop = df[(df["Date"] == date_val) & (df["Cage"] == cage_val) & (df["name"] == drop3.value) & (df["Night-Phase"] == night_phase_val)]
#         plt.figure()
#         # x=temp_df_loop[temp_df_loop.RFidA.isin(temp_df_loop.RFidA.unique())]['Bin']
#         # y=temp_df_loop[temp_df_loop.RFidA.isin(temp_df_loop.RFidA.unique())]["numberOfEvents"]
#         sns.lineplot(temp_df_loop,y='numberOfEvents',x='Bin',hue="GenoA", style='RFidA')
#         plt.title(f'Numbers of {drop3.value} per bin of each mouse')
#         plt.ylabel(f'Numbers of {drop3.value}')
#         plt.show()

def plot_data(Date, Cage, Night_Phase, Event):
    clear_output()
    filtered_df = df[df["Date"].isin(Date) & df["Cage"].isin(Cage) & df["Night-Phase"].isin(Night_Phase) & df["name"].isin([Event])]
    # Use filtered_df to generate plots using matplotlib, seaborn, or other plotting library
    # Example:
    sns.lineplot(filtered_df,y='numberOfEvents',x='Bin',hue="GenoA", style='RFidA')
    plt.title(f'Numbers of {drop3.value} per bin of each mouse')
    plt.ylabel(f'Numbers of {drop3.value}')
    plt.show()

# adapt_plot = interact(update_dropdown, date=drop1, cage=drop2, event=drop3, night_phase=drop4)
# adapt_plot

# interact(update_dropdown, drop1=tab.children[0].children[0], drop2=tab.children[0].children[1], drop4=tab.children[0].children[2], drop3=tab.children[0].children[3])

# On utilise interact pour rendre les widgets interactifs
# interact(update_dropdown, date=drop1, cage=drop2, night_phase=drop4, event=drop3)
interactive_plot = widgets.interactive_output(plot_data, {'Date': drop1, 'Cage': drop2, 'Night_Phase': drop4, 'Event': drop3})

display(interactive_plot)
# Out:
# C:\Users\paulc\AppData\Local\Temp\ipykernel_20004\3389543067.py:19: DtypeWarning:
#
# Columns (18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
# Tab(children=(HBox(children=(Button(description='Reset', style=ButtonStyle()), Button(description='Update', st…
# Output()

# %%
import ipywidgets as widgets
from ipywidgets import *
from ipywidgets import interactive
from ipywidgets import interact
from ipywidgets import HBox, VBox
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
import csv
import cufflinks as cf
import itertools

# Read csv
os.chdir("C:/Users/paulc/Desktop/Stage/lmt-analysis-2022/LMT/scripts/Dataframes/")
df = pd.read_csv("Merge.csv")

date = df["Date"].unique()
cage = df["Cage"].unique()
night_phase = df["Night-Phase"].unique()
bins = df["Bin"].unique()
event = df["name"].unique()

# Création widgets
drop1 = widgets.SelectMultiple(options=date, rows=5, description='Date', disabled=False)
# drop1 = widgets.Dropdown(options=date, value=221013, description='Date:', disabled=False)
drop2 = widgets.SelectMultiple(options=cage, rows=5, description='Cage', disabled=False)
# drop2 = widgets.Dropdown(options=cage, value='Cage1', description='Cage:', disabled=False)
# drop3 = widgets.SelectMultiple(options=event, value=['Move'], rows=5, description='Event', disabled=False)
drop3 = widgets.Dropdown(options=event, value=event[0], description='Event:', disabled=False)
drop4 = widgets.SelectMultiple(options=night_phase, rows=5, description='Night_Phase', disabled=False)
# drop4 = widgets.Dropdown(options=night_phase, value=1, description='Night_Phase:', disabled=False)

# Pour sélectionner plusieurs Dates
def update_options(change):
    # Filtrer les données du DataFrame en fonction des valeurs sélectionnées dans drop1
    filtered_df = df[df['Date'].isin(drop1.value)]
    
    # Mettre à jour les options de drop2 avec les valeurs uniques de la colonne "Cage" pour les données filtrées
    options = filtered_df['Cage'].unique()
    drop2.options = options
    
    # Conserver les valeurs sélectionnées dans drop2 si elles sont encore valides après la mise à jour des options
    drop2.value = list(set(drop2.value) & set(options))
    
    # Mettre à jour les options de drop4 avec les valeurs uniques de la colonne "Night-Phase" pour les données filtrées
    options = filtered_df['Night-Phase'].unique()
    drop4.options = options
    
    # Conserver les valeurs sélectionnées dans drop4 si elles sont encore valides après la mise à jour des options
    drop4.value = list(set(drop4.value) & set(options))

# Assigner la fonction update_options à l'événement "observe" de drop1
drop1.observe(update_options, names='value')

def on_change_cage(change):
    if drop2.value:
        current_value = drop1.value
        if current_value:
            current_value = current_value[0]
        options = df['Date'][df['Cage'] == drop2.value[0]].unique()
        drop1.options = options
        drop1.value = list(set(current_value) & set(options))

drop2.observe(on_change_cage)

def on_change_date(change):
    if drop1.value:
        current_value = drop2.value
        if current_value:
            current_value = current_value[0]
        options = df['Cage'][df['Date'].isin(drop1.value)].unique()
        drop2.options = options
        if current_value in options:
            drop2.value = current_value
        else:
            drop2.value = ()

drop1.observe(on_change_date)

def update_temp_df(change):
    # Mise à jour de temp_df en fonction de la sélection actuelle des widgets
    global temp_df
    temp_df = df[(df["Date"].isin((drop1.value))) & (df["Cage"].isin((drop2.value))) & (df["name"] == drop3.value) & (df["Night-Phase"].isin((drop4.value)))]

# Initialisation de temp_df en fonction de la sélection initiale des widgets
temp_df = df[(df["Date"].isin((drop1.value))) & (df["Cage"].isin((drop2.value))) & (df["name"] == drop3.value) & (df["Night-Phase"].isin((drop4.value)))]

# Observation des widgets pour mettre à jour temp_df lorsque la sélection est modifiée
drop1.observe(update_temp_df, 'value')
drop2.observe(update_temp_df, 'value')
drop3.observe(update_temp_df, 'value')
drop4.observe(update_temp_df, 'value')

# Préparation pour le tracé
bins = temp_df['Bin'].unique()
animals = temp_df['RFidA'].unique()
nbrAnimals = len(animals)
nbrEvents = {}

# Fonction pour afficher le plot en fonction des choix de l'utilisateur
def update_dropdown(date, cage, night_phase, event):
    for date_val, cage_val, night_phase_val in itertools.product(date, cage, night_phase):
        info = f"La date choisie est le {date_val}, il s'agit de la {cage_val.lower()} pour l'évènement '{drop3.value}' durant la phase {night_phase_val} de nuit !"
        display(info)
        temp_df_loop = df[(df["Date"] == date_val) & (df["Cage"] == cage_val) & (df["name"] == drop3.value) & (df["Night-Phase"] == night_phase_val)]
        plt.figure()
        # x=temp_df_loop[temp_df_loop.RFidA.isin(temp_df_loop.RFidA.unique())]['Bin']
        # y=temp_df_loop[temp_df_loop.RFidA.isin(temp_df_loop.RFidA.unique())]["numberOfEvents"]
        sns.lineplot(temp_df_loop,y='numberOfEvents',x='Bin',hue="GenoA", style='RFidA')
        plt.title(f'Numbers of {drop3.value} per bin of each mouse')
        plt.ylabel(f'Numbers of {drop3.value}')
        plt.show()

# # #interact function in isolation
# adapt_plot = interact(update_dropdown, date=drop1, cage=drop2, event=drop3, night_phase=drop4)
# # tab_nest.children = [VBox(children = adapt_plot.children)]
# # display(tab_nest)
# adapt_plot

tab1 = HBox(children=[drop1, drop2, drop4, drop3])
tab = widgets.Tab(children=[tab1])
tab.set_title(0, 'test1')
display(tab)
interact(update_dropdown, date=drop1, cage=drop2, night_phase=drop4, event=drop3)
# plt.show()
# Out:
# C:\Users\paulc\AppData\Local\Temp\ipykernel_21048\2935001599.py:18: DtypeWarning:
#
# Columns (18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
# Tab(children=(HBox(children=(SelectMultiple(description='Date', options=(221013, 221017, 221018, 221019, 22102…
# interactive(children=(SelectMultiple(description='Date', options=(221013, 221017, 221018, 221019, 221020, 2210…
# <function __main__.update_dropdown(date, cage, night_phase, event)>

# %%
# NE PAS TOUCHER!!

from IPython.display import Markdown
import ipywidgets as widgets
from ipywidgets import *
from ipywidgets import interactive
from ipywidgets import interact
from ipywidgets import HBox, VBox
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
import csv
import cufflinks as cf
import itertools
import scipy
# %matplotlib tk

# Read csv
os.chdir("C:/Users/paulc/Desktop/Stage/lmt-analysis-2022/LMT/scripts/Dataframes/")
df = pd.read_csv("Merge.csv")

date = df["Date"].unique()
cage = df["Cage"].unique()
night_phase = df["Night-Phase"].unique()
bins = df["Bin"].unique()
event = df["name"].unique()

reset_button = widgets.Button(description='Reset')
drop1 = widgets.SelectMultiple(options=date, rows=5, description='Date', disabled=False)
# drop1 = widgets.Dropdown(options=date, value=221013, description='Date:', disabled=False)
drop2 = widgets.SelectMultiple(options=cage, rows=5, description='Cage', disabled=False)
# drop2 = widgets.Dropdown(options=cage, value='Cage1', description='Cage:', disabled=False)
# drop3 = widgets.SelectMultiple(options=event, value=['Move'], rows=5, description='Event', disabled=False)
drop3 = widgets.Dropdown(options=event, value=event[1], description='Event:', disabled=False)
drop4 = widgets.SelectMultiple(options=night_phase, rows=5, description='Night_Phase', disabled=False)
# drop4 = widgets.Dropdown(options=night_phase, value=1, description='Night_Phase:', disabled=False)

# Test1

# def on_change_cage(change):
#     options = df['Date'][df['Cage'] == drop2.value].unique()
#     drop1.options = options
#     drop1.value = list(set(drop1.value) & set(options))

# drop2.observe(on_change_cage)

# def on_change_date(change):
#     options = df['Cage'][df['Date'].isin(drop1.value)].unique()
#     drop2.options = options
#     drop2.value = list(set(drop2.value) & set(options))

# drop1.observe(on_change_date)

# Test2

# first_call = True

# def on_change_date(change):
#     global first_call
#     drop2.options = df['Cage'][df['Date'] == drop1.value].unique()
#     drop4.options = df['Night-Phase'][df['Date'] == drop1.value].unique()
#     first_call = True

# drop1.observe(on_change_date)

# def on_change_cage(change):
#     global first_call
#     if first_call:
#         drop1.options = df['Date'][df['Cage'] == drop2.value].unique()
#         first_call = False
#     else:
#         drop1.value = ()
#         drop1.options = df['Date'][df['Cage'] == drop2.value].unique()

# drop2.observe(on_change_cage)

# def on_change(change):
#     drop2.options = df['Cage'][df['Date'] == drop1.value].unique()
#     drop4.options = df['Night-Phase'][df['Date'] == drop1.value].unique()
#     # drop1.options = df['Date'][df['Cage'] == drop2.value].unique()

# drop1.observe(on_change)
# # drop2.observe(on_change)

def reset_selections(b):
    drop1.value = ()
    drop2.options = df['Cage'].unique()
    drop4.options = df['Night-Phase'].unique()

reset_button.on_click(reset_selections)

# Pour sélectionner plusieurs Dates
def update_options(change):
    # Filtrer les données du DataFrame en fonction des valeurs sélectionnées dans drop1
    filtered_df = df[df['Date'].isin(drop1.value)]
    
    # Mettre à jour les options de drop2 avec les valeurs uniques de la colonne "Cage" pour les données filtrées
    options = filtered_df['Cage'].unique()
    drop2.options = options
    
    # Conserver les valeurs sélectionnées dans drop2 si elles sont encore valides après la mise à jour des options
    drop2.value = list(set(drop2.value) & set(options))
    
    # Mettre à jour les options de drop4 avec les valeurs uniques de la colonne "Night-Phase" pour les données filtrées
    options = filtered_df['Night-Phase'].unique()
    drop4.options = options
    
    # Conserver les valeurs sélectionnées dans drop4 si elles sont encore valides après la mise à jour des options
    drop4.value = list(set(drop4.value) & set(options))

# Assigner la fonction update_options à l'événement "observe" de drop1
drop1.observe(update_options, names='value')

def update_temp_df(change):
    # Mise à jour de temp_df en fonction de la sélection actuelle des widgets
    global temp_df
    temp_df = df[(df["Date"].isin((drop1.value))) & (df["Cage"].isin((drop2.value))) & (df["name"] == drop3.value) & (df["Night-Phase"].isin((drop4.value)))]

# Initialisation de temp_df en fonction de la sélection initiale des widgets
temp_df = df[(df["Date"].isin((drop1.value))) & (df["Cage"].isin((drop2.value))) & (df["name"] == drop3.value) & (df["Night-Phase"].isin((drop4.value)))]

# Observation des widgets pour mettre à jour temp_df lorsque la sélection est modifiée
drop1.observe(update_temp_df, 'value')
drop2.observe(update_temp_df, 'value')
drop3.observe(update_temp_df, 'value')
drop4.observe(update_temp_df, 'value')

# Préparation pour le tracé
bins = temp_df['Bin'].unique()
animals = temp_df['RFidA'].unique()
nbrAnimals = len(animals)
nbrEvents = {}

# Fonction pour afficher le plot en fonction des choix de l'utilisateur
def update_dropdown(date, cage, night_phase, event):
    for date_val, cage_val, night_phase_val in itertools.product(date, cage, night_phase):
        # info = f"La date choisie est le {date_val}, il s'agit de la {cage_val.lower()} pour l'évènement '{drop3.value}' durant la phase {night_phase_val} de nuit !"
        display(Markdown(f"<h3>La date choisie est le {date_val}, il s'agit de la {cage_val.lower()} pour l'évènement '{drop3.value}' durant la phase {night_phase_val} de nuit !</h3>"))
        global temp_df_loop
        temp_df_loop = df[(df["Date"] == date_val) & (df["Cage"] == cage_val) & (df["name"] == drop3.value) & (df["Night-Phase"] == night_phase_val)]
        # plt.figure(figsize=(18, 6))
        # fig, (line_ax, bar_ax) = plt.subplots(1, 2, figsize=(20,5))
        # fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6), width_ratios=[1, 1])
        fig, ax1 = plt.subplots(figsize=(12,6))
        ax2 = fig.add_axes([1, 0.25, 0.25, 0.5])
        # x=temp_df_loop[temp_df_loop.RFidA.isin(temp_df_loop.RFidA.unique())]['Bin']
        # y=temp_df_loop[temp_df_loop.RFidA.isin(temp_df_loop.RFidA.unique())]["numberOfEvents"]
        sns.lineplot(temp_df_loop, y='numberOfEvents', x='Bin', hue="GenoA", style='RFidA', palette={'Amphet':'red', 'NaCl':'blue'}, ax=ax1)
        ax1.set_title(f'Numbers of {drop3.value} per bin of each mouse')
        ax1.set_ylabel(f'Numbers of {drop3.value}')
        sns.barplot(data=temp_df_loop, y='numberOfEvents', x="GenoA", palette={'Amphet':'red', 'NaCl':'blue'}, ax=ax2)
        ax2.set_title("A barplot")
        plt.show()
        mean_AMPHET = temp_df_loop[temp_df_loop["GenoA"] == 'Amphet']["numberOfEvents"]
        mean_NACL = temp_df_loop[temp_df_loop["GenoA"] == 'NaCl']["numberOfEvents"]
        stat, pvalue = scipy.stats.ttest_ind(mean_NACL,mean_AMPHET)
        display(Markdown(f"<h3>La statistique du t-test est de {stat} et la p-value est de {pvalue}</h3>"))

# # #interact function in isolation
# adapt_plot = interact(update_dropdown, date=drop1, cage=drop2, event=drop3, night_phase=drop4)
# # tab_nest.children = [VBox(children = adapt_plot.children)]
# # display(tab_nest)
# adapt_plot

tab1 = HBox(children=[reset_button, drop1, drop2, drop4, drop3])
tab = widgets.Tab(children=[tab1])
tab.set_title(0, 'test1')
display(tab)
interact(update_dropdown, date=drop1, cage=drop2, event=drop3, night_phase=drop4)
plt.show()

# Faire un on_change de Date quand on clique sur la Cage après avoir choisi la Date

# %%
# NE PAS TOUCHER!!

from IPython.display import Markdown
import ipywidgets as widgets
from ipywidgets import *
from ipywidgets import interactive
from ipywidgets import interact
from ipywidgets import HBox, VBox
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
import csv
import cufflinks as cf
import itertools
import scipy
# %matplotlib tk

# Read csv
os.chdir("C:/Users/paulc/Desktop/Stage/lmt-analysis-2022/LMT/scripts/Dataframes/")
df = pd.read_csv("Merge.csv")

date = df["Date"].unique()
cage = df["Cage"].unique()
night_phase = df["Night-Phase"].unique()
bins = df["Bin"].unique()
event = df["name"].unique()

reset_button = widgets.Button(description='Reset')
drop1 = widgets.SelectMultiple(options=date, rows=5, description='Date', disabled=False)
# drop1 = widgets.Dropdown(options=date, value=221013, description='Date:', disabled=False)
drop2 = widgets.SelectMultiple(options=cage, rows=5, description='Cage', disabled=False)
# drop2 = widgets.Dropdown(options=cage, value='Cage1', description='Cage:', disabled=False)
# drop3 = widgets.SelectMultiple(options=event, value=['Move'], rows=5, description='Event', disabled=False)
drop3 = widgets.Dropdown(options=event, value=event[1], description='Event:', disabled=False)
drop4 = widgets.SelectMultiple(options=night_phase, rows=5, description='Night_Phase', disabled=False)
# drop4 = widgets.Dropdown(options=night_phase, value=1, description='Night_Phase:', disabled=False)

# Test1

# def on_change_cage(change):
#     options = df['Date'][df['Cage'] == drop2.value].unique()
#     drop1.options = options
#     drop1.value = list(set(drop1.value) & set(options))

# drop2.observe(on_change_cage)

# def on_change_date(change):
#     options = df['Cage'][df['Date'].isin(drop1.value)].unique()
#     drop2.options = options
#     drop2.value = list(set(drop2.value) & set(options))

# drop1.observe(on_change_date)

# Test2

# first_call = True

# def on_change_date(change):
#     global first_call
#     drop2.options = df['Cage'][df['Date'] == drop1.value].unique()
#     drop4.options = df['Night-Phase'][df['Date'] == drop1.value].unique()
#     first_call = True

# drop1.observe(on_change_date)

# def on_change_cage(change):
#     global first_call
#     if first_call:
#         drop1.options = df['Date'][df['Cage'] == drop2.value].unique()
#         first_call = False
#     else:
#         drop1.value = ()
#         drop1.options = df['Date'][df['Cage'] == drop2.value].unique()

# drop2.observe(on_change_cage)

# def on_change(change):
#     drop2.options = df['Cage'][df['Date'] == drop1.value].unique()
#     drop4.options = df['Night-Phase'][df['Date'] == drop1.value].unique()
#     # drop1.options = df['Date'][df['Cage'] == drop2.value].unique()

# drop1.observe(on_change)
# # drop2.observe(on_change)

def reset_selections(b):
    drop1.value = ()
    drop2.options = df['Cage'].unique()
    drop4.options = df['Night-Phase'].unique()

reset_button.on_click(reset_selections)

# Pour sélectionner plusieurs Dates
def update_options(change):
    # Filtrer les données du DataFrame en fonction des valeurs sélectionnées dans drop1
    filtered_df = df[df['Date'].isin(drop1.value)]
    
    # Mettre à jour les options de drop2 avec les valeurs uniques de la colonne "Cage" pour les données filtrées
    options = filtered_df['Cage'].unique()
    drop2.options = options
    
    # Conserver les valeurs sélectionnées dans drop2 si elles sont encore valides après la mise à jour des options
    drop2.value = list(set(drop2.value) & set(options))
    
    # Mettre à jour les options de drop4 avec les valeurs uniques de la colonne "Night-Phase" pour les données filtrées
    options = filtered_df['Night-Phase'].unique()
    drop4.options = options
    
    # Conserver les valeurs sélectionnées dans drop4 si elles sont encore valides après la mise à jour des options
    drop4.value = list(set(drop4.value) & set(options))

# Assigner la fonction update_options à l'événement "observe" de drop1
drop1.observe(update_options, names='value')

def update_temp_df(change):
    # Mise à jour de temp_df en fonction de la sélection actuelle des widgets
    global temp_df
    temp_df = df[(df["Date"].isin((drop1.value))) & (df["Cage"].isin((drop2.value))) & (df["name"] == drop3.value) & (df["Night-Phase"].isin((drop4.value)))]

# Initialisation de temp_df en fonction de la sélection initiale des widgets
temp_df = df[(df["Date"].isin((drop1.value))) & (df["Cage"].isin((drop2.value))) & (df["name"] == drop3.value) & (df["Night-Phase"].isin((drop4.value)))]

# Observation des widgets pour mettre à jour temp_df lorsque la sélection est modifiée
drop1.observe(update_temp_df, 'value')
drop2.observe(update_temp_df, 'value')
drop3.observe(update_temp_df, 'value')
drop4.observe(update_temp_df, 'value')

# Préparation pour le tracé
bins = temp_df['Bin'].unique()
animals = temp_df['RFidA'].unique()
nbrAnimals = len(animals)
nbrEvents = {}

# Fonction pour afficher le plot en fonction des choix de l'utilisateur
def update_dropdown(date, cage, night_phase, event):
    for date_val, cage_val, night_phase_val in itertools.product(date, cage, night_phase):
        # info = f"La date choisie est le {date_val}, il s'agit de la {cage_val.lower()} pour l'évènement '{drop3.value}' durant la phase {night_phase_val} de nuit !"
        display(Markdown(f"<h3>La date choisie est le {date_val}, il s'agit de la {cage_val.lower()} pour l'évènement '{drop3.value}' durant la phase {night_phase_val} de nuit !</h3>"))
        global temp_df_loop
        temp_df_loop = df[(df["Date"] == date_val) & (df["Cage"] == cage_val) & (df["name"] == drop3.value) & (df["Night-Phase"] == night_phase_val)]
        # plt.figure(figsize=(18, 6))
        # fig, (line_ax, bar_ax) = plt.subplots(1, 2, figsize=(20,5))
        # fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6), width_ratios=[1, 1])
        fig, ax1 = plt.subplots(figsize=(12,6))
        ax2 = fig.add_axes([1, 0.25, 0.25, 0.5])
        # x=temp_df_loop[temp_df_loop.RFidA.isin(temp_df_loop.RFidA.unique())]['Bin']
        # y=temp_df_loop[temp_df_loop.RFidA.isin(temp_df_loop.RFidA.unique())]["numberOfEvents"]
        sns.lineplot(temp_df_loop, y='numberOfEvents', x='Bin', hue="GenoA", style='RFidA', palette={'Amphet':'red', 'NaCl':'blue'}, ax=ax1)
        ax1.set_title(f'Numbers of {drop3.value} per bin of each mouse')
        ax1.set_ylabel(f'Numbers of {drop3.value}')
        sns.barplot(data=temp_df_loop, y='numberOfEvents', x="GenoA", palette={'Amphet':'red', 'NaCl':'blue'}, ax=ax2)
        ax2.set_title("A barplot")
        plt.show()
        mean_AMPHET = temp_df_loop[temp_df_loop["GenoA"] == 'Amphet']["numberOfEvents"]
        mean_NACL = temp_df_loop[temp_df_loop["GenoA"] == 'NaCl']["numberOfEvents"]
        stat, pvalue = scipy.stats.ttest_ind(mean_NACL,mean_AMPHET)
        display(Markdown(f"<h3>La statistique du t-test est de {stat} et la p-value est de {pvalue}</h3>"))

# # #interact function in isolation
# adapt_plot = interact(update_dropdown, date=drop1, cage=drop2, event=drop3, night_phase=drop4)
# # tab_nest.children = [VBox(children = adapt_plot.children)]
# # display(tab_nest)
# adapt_plot

tab1 = HBox(children=[reset_button, drop1, drop2, drop4, drop3])
tab = widgets.Tab(children=[tab1])
tab.set_title(0, 'test1')
display(tab)
interact(update_dropdown, date=drop1, cage=drop2, event=drop3, night_phase=drop4)
plt.show()

# Faire un on_change de Date quand on clique sur la Cage après avoir choisi la Date
# Out:
# C:\Users\paulc\AppData\Local\Temp\ipykernel_20004\748202396.py:23: DtypeWarning:
#
# Columns (18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
# Tab(children=(HBox(children=(Button(description='Reset', style=ButtonStyle()), SelectMultiple(description='Dat…
# interactive(children=(SelectMultiple(description='Date', options=(221013, 221017, 221018, 221019, 221020, 2210…

# %%
# NE PAS TOUCHER!!

from IPython.display import Markdown
import ipywidgets as widgets
from ipywidgets import *
from ipywidgets import interactive
from ipywidgets import interact
from ipywidgets import HBox, VBox
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
import csv
import cufflinks as cf
import itertools
import scipy
# %matplotlib tk

# Read csv
os.chdir("C:/Users/paulc/Desktop/Stage/lmt-analysis-2022/LMT/scripts/Dataframes/")
df = pd.read_csv("Merge.csv")

date = df["Date"].unique()
cage = df["Cage"].unique()
night_phase = df["Night-Phase"].unique()
bins = df["Bin"].unique()
event = df["name"].unique()

reset_button = widgets.Button(description='Reset')
drop1 = widgets.SelectMultiple(options=date, rows=5, description='Date', disabled=False)
# drop1 = widgets.Dropdown(options=date, value=221013, description='Date:', disabled=False)
drop2 = widgets.SelectMultiple(options=cage, rows=5, description='Cage', disabled=False)
# drop2 = widgets.Dropdown(options=cage, value='Cage1', description='Cage:', disabled=False)
# drop3 = widgets.SelectMultiple(options=event, value=['Move'], rows=5, description='Event', disabled=False)
drop3 = widgets.Dropdown(options=event, value=event[1], description='Event:', disabled=False)
drop4 = widgets.SelectMultiple(options=night_phase, rows=5, description='Night_Phase', disabled=False)
# drop4 = widgets.Dropdown(options=night_phase, value=1, description='Night_Phase:', disabled=False)

# Test1

# def on_change_cage(change):
#     options = df['Date'][df['Cage'] == drop2.value].unique()
#     drop1.options = options
#     drop1.value = list(set(drop1.value) & set(options))

# drop2.observe(on_change_cage)

# def on_change_date(change):
#     options = df['Cage'][df['Date'].isin(drop1.value)].unique()
#     drop2.options = options
#     drop2.value = list(set(drop2.value) & set(options))

# drop1.observe(on_change_date)

# Test2

# first_call = True

# def on_change_date(change):
#     global first_call
#     drop2.options = df['Cage'][df['Date'] == drop1.value].unique()
#     drop4.options = df['Night-Phase'][df['Date'] == drop1.value].unique()
#     first_call = True

# drop1.observe(on_change_date)

# def on_change_cage(change):
#     global first_call
#     if first_call:
#         drop1.options = df['Date'][df['Cage'] == drop2.value].unique()
#         first_call = False
#     else:
#         drop1.value = ()
#         drop1.options = df['Date'][df['Cage'] == drop2.value].unique()

# drop2.observe(on_change_cage)

# def on_change(change):
#     drop2.options = df['Cage'][df['Date'] == drop1.value].unique()
#     drop4.options = df['Night-Phase'][df['Date'] == drop1.value].unique()
#     # drop1.options = df['Date'][df['Cage'] == drop2.value].unique()

# drop1.observe(on_change)
# # drop2.observe(on_change)

def reset_selections(b):
    drop1.value = ()
    drop2.options = df['Cage'].unique()
    drop4.options = df['Night-Phase'].unique()

reset_button.on_click(reset_selections)

# Pour sélectionner plusieurs Dates
def update_options(change):
    # Filtrer les données du DataFrame en fonction des valeurs sélectionnées dans drop1
    filtered_df = df[df['Date'].isin(drop1.value)]
    
    # Mettre à jour les options de drop2 avec les valeurs uniques de la colonne "Cage" pour les données filtrées
    options = filtered_df['Cage'].unique()
    drop2.options = options
    
    # Conserver les valeurs sélectionnées dans drop2 si elles sont encore valides après la mise à jour des options
    drop2.value = list(set(drop2.value) & set(options))
    
    # Mettre à jour les options de drop4 avec les valeurs uniques de la colonne "Night-Phase" pour les données filtrées
    options = filtered_df['Night-Phase'].unique()
    drop4.options = options
    
    # Conserver les valeurs sélectionnées dans drop4 si elles sont encore valides après la mise à jour des options
    drop4.value = list(set(drop4.value) & set(options))

# Assigner la fonction update_options à l'événement "observe" de drop1
drop1.observe(update_options, names='value')

def update_temp_df(change):
    # Mise à jour de temp_df en fonction de la sélection actuelle des widgets
    global temp_df
    temp_df = df[(df["Date"].isin((drop1.value))) & (df["Cage"].isin((drop2.value))) & (df["name"] == drop3.value) & (df["Night-Phase"].isin((drop4.value)))]

# Initialisation de temp_df en fonction de la sélection initiale des widgets
temp_df = df[(df["Date"].isin((drop1.value))) & (df["Cage"].isin((drop2.value))) & (df["name"] == drop3.value) & (df["Night-Phase"].isin((drop4.value)))]

# Observation des widgets pour mettre à jour temp_df lorsque la sélection est modifiée
drop1.observe(update_temp_df, 'value')
drop2.observe(update_temp_df, 'value')
drop3.observe(update_temp_df, 'value')
drop4.observe(update_temp_df, 'value')

# Préparation pour le tracé
bins = temp_df['Bin'].unique()
animals = temp_df['RFidA'].unique()
nbrAnimals = len(animals)
nbrEvents = {}

# Fonction pour afficher le plot en fonction des choix de l'utilisateur
def update_dropdown(date, cage, night_phase, event):
    for date_val, cage_val, night_phase_val in itertools.product(date, cage, night_phase):
        # info = f"La date choisie est le {date_val}, il s'agit de la {cage_val.lower()} pour l'évènement '{drop3.value}' durant la phase {night_phase_val} de nuit !"
        display(Markdown(f"<h3>La date choisie est le {date_val}, il s'agit de la {cage_val.lower()} pour l'évènement '{drop3.value}' durant la phase {night_phase_val} de nuit !</h3>"))
        global temp_df_loop
        temp_df_loop = df[(df["Date"] == date_val) & (df["Cage"] == cage_val) & (df["name"] == drop3.value) & (df["Night-Phase"] == night_phase_val)]
        # plt.figure(figsize=(18, 6))
        # fig, (line_ax, bar_ax) = plt.subplots(1, 2, figsize=(20,5))
        # fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6), width_ratios=[1, 1])
        fig, ax1 = plt.subplots(figsize=(12,6))
        ax2 = fig.add_axes([1, 0.25, 0.25, 0.5])
        # x=temp_df_loop[temp_df_loop.RFidA.isin(temp_df_loop.RFidA.unique())]['Bin']
        # y=temp_df_loop[temp_df_loop.RFidA.isin(temp_df_loop.RFidA.unique())]["numberOfEvents"]
        sns.lineplot(temp_df_loop, y='numberOfEvents', x='Bin', hue="GenoA", style='RFidA', palette={'Amphet':'red', 'NaCl':'blue'}, ax=ax1)
        ax1.set_title(f'Numbers of {drop3.value} per bin of each mouse')
        ax1.set_ylabel(f'Numbers of {drop3.value}')
        sns.barplot(data=temp_df_loop, y='numberOfEvents', x="GenoA", palette={'Amphet':'red', 'NaCl':'blue'}, ax=ax2)
        ax2.set_title("A barplot")
        plt.show()
        mean_AMPHET = temp_df_loop[temp_df_loop["GenoA"] == 'Amphet']["numberOfEvents"]
        mean_NACL = temp_df_loop[temp_df_loop["GenoA"] == 'NaCl']["numberOfEvents"]
        stat, pvalue = scipy.stats.ttest_ind(mean_NACL,mean_AMPHET)
        display(Markdown(f"<h3>La statistique du t-test est de {stat} et la p-value est de {pvalue}</h3>"))

# # #interact function in isolation
# adapt_plot = interact(update_dropdown, date=drop1, cage=drop2, event=drop3, night_phase=drop4)
# # tab_nest.children = [VBox(children = adapt_plot.children)]
# # display(tab_nest)
# adapt_plot

tab1 = HBox(children=[reset_button, drop1, drop2, drop4, drop3])
tab = widgets.Tab(children=[tab1])
tab.set_title(0, 'test1')
display(tab)
interact(update_dropdown, date=drop1, cage=drop2, event=drop3, night_phase=drop4)
plt.show()

# Faire un on_change de Date quand on clique sur la Cage après avoir choisi la Date
# Out:
# C:\Users\paulc\AppData\Local\Temp\ipykernel_14384\748202396.py:23: DtypeWarning:
#
# Columns (18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
# Tab(children=(HBox(children=(Button(description='Reset', style=ButtonStyle()), SelectMultiple(description='Dat…
# interactive(children=(SelectMultiple(description='Date', options=(221013, 221017, 221018, 221019, 221020, 2210…
